# %%
import requests
from bs4 import BeautifulSoup

import datetime as dt
from dateutil import rrule

import pandas as pd
import json

# %%
std_date = pd.to_datetime('2024-08-01')
print(f"{std_date.strftime(r'%Y-%m')} Month start!")
print(f"{std_date.strftime(r'%Y-%m')} Month start!")
# Out:
# 2024-08 Month start!
# 2024-08 Month start!

# %%
df = pd.read_csv('news_naver_it.csv')
df
# Out:
#                                                    title   press  \
# 0                 뉴욕증시, 3.5일로 줄어든 7월 첫 주·하반기 첫 거래일…보합 출발    연합뉴스
# 1                      외환거래시간 연장 첫날, 은행들 비상대기…환율 급등락은 없어    서울경제
# 2               “부럽다 미국·인도”...볼때마다 한숨 코스피, 그나마 브라질에 위안받네    매일경제
# 3                      게임스톱 사태 주도 '대장개미' 이번엔 반려동물 관련주 타깃    연합뉴스
# 4                            뉴욕증시, 고용지표·FOMC 의사록 대기하며 상승   아시아경제
# ...                                                  ...     ...
# 41983           [1보] 주미대사 "北위성발사, 유엔 대북제재 위반…응분 대가 치를 것"    연합뉴스
# 41984                  양자컴퓨팅 시대에 쓰여질 광스위치 양자 메모리 원천기술 개발    서울경제
# 41985        [지금은 과학] 빛 알갱이 하나하나에 정보 심는다…光양자 메모리 원천기술 개발  아이뉴스24
# 41986  [뉴테크] 양자컴퓨팅 시대의 ‘CD롬’ 한국 과학자가 만든다… 광자 이용한 데이터 ...    조선비즈
# 41987                 양자컴퓨터용 '3D 광양자 메모리' 원천기술 개발…네이처 게재    연합뉴스
#
#                                                      url        date   sec2
# 0      https://n.news.naver.com/mnews/article/001/001...  2024-07-01     증권
# 1      https://n.news.naver.com/mnews/article/011/000...  2024-07-01     증권
# 2      https://n.news.naver.com/mnews/article/009/000...  2024-07-01     증권
# 3      https://n.news.naver.com/mnews/article/001/001...  2024-07-01     증권
# 4      https://n.news.naver.com/mnews/article/277/000...  2024-07-01     증권
# ...                                                  ...         ...    ...
# 41983  https://n.news.naver.com/mnews/article/001/001...  2023-06-01  과학 일반
# 41984  https://n.news.naver.com/mnews/article/011/000...  2023-06-01  과학 일반
# 41985  https://n.news.naver.com/mnews/article/031/000...  2023-06-01  과학 일반
# 41986  https://n.news.naver.com/mnews/article/366/000...  2023-06-01  과학 일반
# 41987  https://n.news.naver.com/mnews/article/001/001...  2023-06-01  과학 일반
#
# [41988 rows x 5 columns]

# %%
def crawling_all(is_test, max_data, day_range):
    print(max_data, day_range)

test_params = {'max_data': 2e4, 'day_range': 3}
crawling_all(is_test=True, **test_params)
# Out:
# 20000.0 3

# %%
params = {'max_data': 2e4, 'day_range': 3}
params = {}

if params:
    print('pppp')
else:
    print('qqqqq')
# Out:
# qqqqq

# %%
df.sec2.unique()
# Out:
# array(['중기/벤처'], dtype=object)

# %%
int(2e5)
# Out:
# 200000

# %%
import pandas as pd

# %%
import datetime as dt
from dateutil import rrule

# %%
type(dt.datetime(2024, 7, 20))
# Out:
# datetime.datetime

# %%
int('200,000'.replace(',', ''))
# Out:
# 200000

# %%
now_date = dt.datetime(2024, 7, 31)
now_date - dt.timedelta(days=1)
now_date.strftime(r'%Y%m%d')
# Out:
# '20240731'

# %%
now_date.strftime(r'%Y%m%d')
# Out:
# '20240701'

# %%
now_date + pd.DateOffset(days=1)
# Out:
# Timestamp('2024-07-02 00:00:00')

# %%
now_date = pd.to_datetime('2024-07-01')
now_date - pd.DateOffset(months=1)
# Out:
# Timestamp('2024-06-01 00:00:00')

# %%
# 최초 생성 이후 mode는 append
if not os.path.exists('output.csv'):
    df.to_csv('output.csv', index=False, mode='w', encoding='utf-8-sig')
else:
    df.to_csv('output.csv', index=False, mode='a', encoding='utf-8-sig', header=False)

# %%
import ast

# %%
x = """{"증권": 258,
"금융": 259,
"부동산": 260,
"산업/재계": 261,
"글로벌 경제": 262,
"경제 일반": 263,
"생활경제": 310,
"중기/벤처": 771}"""
eval(x)
# Out:
# {'증권': 258,
#  '금융': 259,
#  '부동산': 260,
#  '산업/재계': 261,
#  '글로벌 경제': 262,
#  '경제 일반': 263,
#  '생활경제': 310,
#  '중기/벤처': 771}

# %% [markdown]
# 일단 첫 화면 가져오는 것부터

# %%
headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/127.0.0.0 Safari/537.36'}

url = "https://news.naver.com/mnews/article/comment/011/0004386530"

res = requests.get(url, headers= headers)
soup = BeautifulSoup(res.text, 'html.parser')
res
# Out:
# <Response [200]>

# %%
res.text
# Out:
# '<!doctype html>\n<html lang="ko" data-useragent="Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/127.0.0.0 Safari/537.36">\n\t<head>\n\t\t<meta charset="utf-8">\n\t\t<meta http-equiv="X-UA-Compatible" content="IE=edge">\n\t\t<meta name="viewport" content="width=device-width, initial-scale=1.0, maximum-scale=1.0, minimum-scale=1.0, user-scalable=no" />\n\t\t<meta property="og:title" content="한동훈, 尹과 갈등설에 &quot;본질 가리려는 시도&quot;">\n\t\t<meta property="og:type" content="article">\n\t\t<meta property="og:url" content="https://n.news.naver.com/mnews/article/011/0004386530">\n\t\t<meta property="og:image" content="https://imgnews.pstatic.net/image/011/2024/08/30/0004386530_001_20240830221810139.jpg?type&#x3D;w800">\n\t\t<meta property="og:description" content="한동훈 국민의힘 대표가 30일 의·정 갈등 해법을 둘러싸고 윤석열 대통령과 갈등을 겪고 있다는 시각에 대해 “갈등 프레임은 본질을 가리려는 시도”라고 반박했다. 한 대표는 이날 자신의 페이스북에서 &quot;우리는 지금 국민">\n\t\t<meta property="og:article:author" content="서울경제 | 네이버">\n\t\t<meta name="twitter:card" content="summary_large_image">\n\t\t<meta name="twitter:title" content="한동훈, 尹과 갈등설에 &quot;본질 가리려는 시도&quot;">\n\t\t<meta name="twitter:site" content="네이버 뉴스">\n\t\t<meta name="twitter:creator" content="서울경제">\n\t\t<meta name="twitter:image" content="https://imgnews.pstatic.net/image/011/2024/08/30/0004386530_001_20240830221810139.jpg?type&#x3D;w800">\n\t\t<meta name="twitter:description" content="한동훈 국민의힘 대표가 30일 의·정 갈등 해법을 둘러싸고 윤석열 대통령과 갈등을 겪고 있다는 시각에 대해 “갈등 프레임은 본질을 가리려는 시도”라고 반박했다. 한 대표는 이날 자신의 페이스북에서 &quot;우리는 지금 국민">\n\t\t<title>한동훈, 尹과 갈등설에 "본질 가리려는 시도"</title>\n\t\t\t<link rel="stylesheet" href="https://static-nnews.pstatic.net/css/min/20240829/news.css">\n\t\t\t<link rel="shortcut icon" type="image/x-icon" href="https://ssl.pstatic.net/static.news/image/news/m/2023/08/21/favicon.ico" />\n\t\t\t<link rel="apple-touch-icon-precomposed" href="https://ssl.pstatic.net/static.news/image/news/m/2018/favicon/06/android_legacy_xxxhpdi_192x192.png" />\n\t\t\t<link rel="apple-touch-icon-precomposed" size="72x72" href="https://ssl.pstatic.net/static.news/image/news/m/2018/favicon/06/android_legacy_hdpi_72X72.png" />\n\t\t\t<link rel="apple-touch-icon-precomposed" size="96x96" href="https://ssl.pstatic.net/static.news/image/news/m/2018/favicon/06/android_legacy_xhdpi_96x96.png" />\n\t\t\t<link rel="apple-touch-icon-precomposed" size="144x144" href="https://ssl.pstatic.net/static.news/image/news/m/2018/favicon/06/android_legacy_xxhpdi_144x144.png" />\n\t\t\t<link rel="apple-touch-icon-precomposed" size="192x192" href="https://ssl.pstatic.net/static.news/image/news/m/2018/favicon/06/android_legacy_xxxhpdi_192x192.png" />\n\t\t\t\t\t<script>\n\t\t\tvar bSupportedIntersectionObserver = "IntersectionObserver" in window;\n\t\t</script>\n\t\t<script async src="https://ssl.pstatic.net/tveta/libs/glad/prod/gfp-core.js"></script>\n\t\t<script>\n\t\t\tvar g_ssc = nsc = "Mnews.v2";\n\t\t\tvar g_default_area = "art";\n\n\t\t\tvar svr = "one-service-r-20240829-240829-162046-7db677bcfc-mkq29";\n\t\t\tvar nelo = {\n\t\t\t\tname : "one-front",\n\t\t\t\turl : "https://kr-col-ext.nelo.navercorp.com/_store",\n\t\t\t\tsampleNumber : 100,\n\t\t\t\tmaxCount : 100,\n\t\t\t\tmaxSendMessage : "로그 전송 최대치 도달"\n\t\t\t};\n\t\t\tvar isGreendot = document.cookie.indexOf("MM_NEW=1") > -1;\n\t\t\tvar isNewGreendot = document.cookie.indexOf("MM_NEW=2") > -1;\n\t\t\tvar domain = "https://n.news.naver.com";\n\t\t\tvar ajaxDomain = "";\n\t\t\tvar newsDomain = "https://news.naver.com";\n\t\t\tvar layoutName = "comment";\n\t\t\tvar layoutType = "article";\n\t\t\tvar isAvailableDarkMode = false;\n\t\t\tvar moduleLoadStatus = -1;\n\n\t\t\tvar article = {\n\t\t\t\tisSubscribe: false,\n\t\t\t\tofficeId: "011",\n\t\t\t\tarticleId: "0004386530",\n\t\t\t\tsectionId : "100",\n\t\t\t\tgdid: "88000108_000000000000000004386530",\n\t\t\t\ttype: "1",\n\t\t\t\tsectionInfo: {\n\t\t\t\t\tfirstSection: "100",\n\t\t\t\t\tsecondSection: "265",\n\t\t\t\t\tthirdSection: "000"\n\t\t\t\t ...

# %%
boxes = soup.select('div#cbox_module')
len(boxes)
# Out:
# 1

# %%
boxes[0]
# Out:
# <div class="_COMMENT _COMMENT_HIDE" id="cbox_module">
# </div>

# %%
import requests

# JavaScript에서 확인한 API URL
url = 'https://n.news.naver.com/mnews/article/comment/011/0004386530'
headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/127.0.0.0 Safari/537.36'}

# 필요하면 헤더나 파라미터도 함께 전송
params = {
'ticket': 'news',
'templateId': 'default_politics_m3',
'pool': 'cbox5',
'_cv': '20240826125754',
'_callback': 'jQuery33107127762849002859_1725265369375',
'lang': 'ko',
'country': 'KR',
'objectId': 'news011%2C0004386530',
'pageSize': '20',
'indexSize': '10',
'listType': 'OBJECT',
'pageType': 'more',
'page': '3',
'currentPage': '2',
'refresh': 'false',
'sort': 'FAVORITE',
'current': '835769803288346711',
'prev': '835742225336893632',
'moreParam.direction': 'next',
'moreParam.prev': '100002100002v06cl1w61grzk0',
'moreParam.next': '100000000000106clbo36d145z',
'includeAllStatus': 'true',
'_': '1725265369380'
}

# GET 요청으로 데이터를 가져옴
response = requests.get(url, headers=headers, params=params)

# 응답을 JSON 형식으로 파싱
# data = response.json()

# print(data)

# %%
response.text
# Out:
# '<!doctype html>\n<html lang="ko" data-useragent="Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/127.0.0.0 Safari/537.36">\n\t<head>\n\t\t<meta charset="utf-8">\n\t\t<meta http-equiv="X-UA-Compatible" content="IE=edge">\n\t\t<meta name="viewport" content="width=device-width, initial-scale=1.0, maximum-scale=1.0, minimum-scale=1.0, user-scalable=no" />\n\t\t<meta property="og:title" content="한동훈, 尹과 갈등설에 &quot;본질 가리려는 시도&quot;">\n\t\t<meta property="og:type" content="article">\n\t\t<meta property="og:url" content="https://n.news.naver.com/mnews/article/011/0004386530">\n\t\t<meta property="og:image" content="https://imgnews.pstatic.net/image/011/2024/08/30/0004386530_001_20240830221810139.jpg?type&#x3D;w800">\n\t\t<meta property="og:description" content="한동훈 국민의힘 대표가 30일 의·정 갈등 해법을 둘러싸고 윤석열 대통령과 갈등을 겪고 있다는 시각에 대해 “갈등 프레임은 본질을 가리려는 시도”라고 반박했다. 한 대표는 이날 자신의 페이스북에서 &quot;우리는 지금 국민">\n\t\t<meta property="og:article:author" content="서울경제 | 네이버">\n\t\t<meta name="twitter:card" content="summary_large_image">\n\t\t<meta name="twitter:title" content="한동훈, 尹과 갈등설에 &quot;본질 가리려는 시도&quot;">\n\t\t<meta name="twitter:site" content="네이버 뉴스">\n\t\t<meta name="twitter:creator" content="서울경제">\n\t\t<meta name="twitter:image" content="https://imgnews.pstatic.net/image/011/2024/08/30/0004386530_001_20240830221810139.jpg?type&#x3D;w800">\n\t\t<meta name="twitter:description" content="한동훈 국민의힘 대표가 30일 의·정 갈등 해법을 둘러싸고 윤석열 대통령과 갈등을 겪고 있다는 시각에 대해 “갈등 프레임은 본질을 가리려는 시도”라고 반박했다. 한 대표는 이날 자신의 페이스북에서 &quot;우리는 지금 국민">\n\t\t<title>한동훈, 尹과 갈등설에 "본질 가리려는 시도"</title>\n\t\t\t<link rel="stylesheet" href="https://static-nnews.pstatic.net/css/min/20240829/news.css">\n\t\t\t<link rel="shortcut icon" type="image/x-icon" href="https://ssl.pstatic.net/static.news/image/news/m/2023/08/21/favicon.ico" />\n\t\t\t<link rel="apple-touch-icon-precomposed" href="https://ssl.pstatic.net/static.news/image/news/m/2018/favicon/06/android_legacy_xxxhpdi_192x192.png" />\n\t\t\t<link rel="apple-touch-icon-precomposed" size="72x72" href="https://ssl.pstatic.net/static.news/image/news/m/2018/favicon/06/android_legacy_hdpi_72X72.png" />\n\t\t\t<link rel="apple-touch-icon-precomposed" size="96x96" href="https://ssl.pstatic.net/static.news/image/news/m/2018/favicon/06/android_legacy_xhdpi_96x96.png" />\n\t\t\t<link rel="apple-touch-icon-precomposed" size="144x144" href="https://ssl.pstatic.net/static.news/image/news/m/2018/favicon/06/android_legacy_xxhpdi_144x144.png" />\n\t\t\t<link rel="apple-touch-icon-precomposed" size="192x192" href="https://ssl.pstatic.net/static.news/image/news/m/2018/favicon/06/android_legacy_xxxhpdi_192x192.png" />\n\t\t\t\t\t<script>\n\t\t\tvar bSupportedIntersectionObserver = "IntersectionObserver" in window;\n\t\t</script>\n\t\t<script async src="https://ssl.pstatic.net/tveta/libs/glad/prod/gfp-core.js"></script>\n\t\t<script>\n\t\t\tvar g_ssc = nsc = "Mnews.v2";\n\t\t\tvar g_default_area = "art";\n\n\t\t\tvar svr = "one-service-r-20240829-240829-162046-7db677bcfc-mkq29";\n\t\t\tvar nelo = {\n\t\t\t\tname : "one-front",\n\t\t\t\turl : "https://kr-col-ext.nelo.navercorp.com/_store",\n\t\t\t\tsampleNumber : 100,\n\t\t\t\tmaxCount : 100,\n\t\t\t\tmaxSendMessage : "로그 전송 최대치 도달"\n\t\t\t};\n\t\t\tvar isGreendot = document.cookie.indexOf("MM_NEW=1") > -1;\n\t\t\tvar isNewGreendot = document.cookie.indexOf("MM_NEW=2") > -1;\n\t\t\tvar domain = "https://n.news.naver.com";\n\t\t\tvar ajaxDomain = "";\n\t\t\tvar newsDomain = "https://news.naver.com";\n\t\t\tvar layoutName = "comment";\n\t\t\tvar layoutType = "article";\n\t\t\tvar isAvailableDarkMode = false;\n\t\t\tvar moduleLoadStatus = -1;\n\n\t\t\tvar article = {\n\t\t\t\tisSubscribe: false,\n\t\t\t\tofficeId: "011",\n\t\t\t\tarticleId: "0004386530",\n\t\t\t\tsectionId : "100",\n\t\t\t\tgdid: "88000108_000000000000000004386530",\n\t\t\t\ttype: "1",\n\t\t\t\tsectionInfo: {\n\t\t\t\t\tfirstSection: "100",\n\t\t\t\t\tsecondSection: "265",\n\t\t\t\t\tthirdSection: "000"\n\t\t\t\t ...

# %%
boxes[0]
# Out:
# <div class="ct_scroll_wrapper">
# <div class="newsct_wrapper _GRID_TEMPLATE_COLUMN _STICKY_CONTENT" id="newsct" role="main"> <div class="newsct" id="ct">
# <div class="media_end_head go_trans">
# <div class="media_end_head_top _LAZY_LOADING_WRAP">
# <a class="media_end_head_top_logo _LAZY_LOADING_ERROR_HIDE" href="http://www.sedaily.com">
# <img alt="서울경제" class="media_end_head_top_logo_img light_type _LAZY_LOADING _LAZY_LOADING_INIT_HIDE" data-src="https://mimgnews.pstatic.net/image/upload/office_logo/011/2020/09/15/logo_011_6_20200915182907.png" height="32" style="display:none;" title="서울경제" width=""/>
# <img alt="서울경제" class="media_end_head_top_logo_img dark_type _LAZY_LOADING _LAZY_LOADING_INIT_HIDE" data-src="https://mimgnews.pstatic.net/image/upload/office_logo/011/2020/09/15/dark_logo_011_6_20200915145150.png" height="32" style="display:none;" title="서울경제" width=""/>
# </a>
# <div class="media_end_head_top_channel _CHANNEL_BUTTON_WRAP" style="display:none;">
# <button class="media_end_head_top_channel_add _CHANNEL_BUTTON" data-clk-add="chmain011" data-clk-remove="chdelete011" data-delay="1000" data-notification="true" data-notification-clk="notru" data-text="구독">구독</button>
# <a class="media_end_head_top_channel_layer _LINK" data-clk="chlook" data-url-type="NAVERAPP_NEWS_CHANNEL" href="#" id="_CHANNEL_LAYER_011_0004386530" style="display: none;">
# <span class="media_end_head_top_channel_layer_text"><strong>서울경제</strong> 언론사 구독되었습니다. <br/>메인 뉴스판에서  주요뉴스를 <br/> 볼 수 있습니다.</span>
# <span class="media_end_head_top_channel_layer_link">보러가기</span>
# </a>
# <p class="media_end_head_top_channel_layer" id="_CHANNEL_REMOVE_LAYER_011_0004386530" style="display: none;">
# <span class="media_end_head_top_channel_layer_text"><strong>서울경제</strong> 언론사 구독 해지되었습니다.</span>
# </p>
# </div>
# <div class="media_end_head_channel">
# <button class="media_end_head_channel_button _TOGGLE" data-target="_PICK_LAYER_011_0004386530" type="button">
# <i class="media_end_head_channel_pick">PICK</i>
# <i class="media_end_head_channel_info">안내</i>
# </button>
# <p class="media_end_head_channel_layer" id="_PICK_LAYER_011_0004386530" style="display: none;">
# <span class="media_end_head_channel_layer_text">언론사가 주요기사로<br/>선정한 기사입니다.</span>
# <a class="media_end_head_channel_layer_link _MOVE_TO_NEWS" href="#">언론사별 바로가기</a>
# <button class="media_end_head_channel_layer_close _CLOSE" data-target="_PICK_LAYER_011_0004386530" type="button">닫기</button>
# </p>
# </div>
# </div>
# <div class="media_end_head_title">
# <h2 class="media_end_head_headline" id="title_area"><span>한동훈, 尹과 갈등설에 "본질 가리려는 시도"</span></h2>
# </div>
# <div class="media_end_head_info nv_notrans media_end_head_info_is_comment">
# <div class="media_end_head_info_datestamp">
# <div class="media_end_head_info_datestamp_bunch">
# <em class="media_end_head_info_datestamp_term">입력</em><span class="media_end_head_info_datestamp_time _ARTICLE_DATE_TIME" data-date-time="2024-08-30 22:18:10" data-date-time-age-in-minutes="3979">2024.08.30. 오후 10:18</span>
# </div>
# </div> <div class="media_end_head_info_origin">
# <div class="media_end_head_info_origin_inner"><a class="media_end_head_info_origin_link" data-clk="rpt.back" href="/mnews/article/011/0004386530">본문보기</a></div>
# </div>
# </div>
# </div>
# <div id="channelBanner" style="display:none;">
# <div class="media_end_channel_banner _LAZY_LOADING_WRAP">
# <a class="media_end_channel_banner_link _CHANNEL_BANNER _CHANNEL_ADD" data-clk-add="cmtbanner011" data-clk-remove="cmtbannergo011" data-notification="true" data-notification-clk="notcb" href="#">
# <div class="media_end_channel_banner_head _LAZY_LOADING_ERROR_HIDE">
# <div class="media_end_channel_banner_img">
# <img alt="서울경제" class="_LAZY_LOADING _LAZY_LOADING_INIT_HIDE" data-src="https://mimgnews.pstatic.net/image/upload/office_logo/011/2022/07/29/logo_011_57_20220729150242.jpg" height="40" style="display:none;" width="40"/>
# </div>
# </div>
# <div class="media_end_channel_banner_body _before _CHANNEL_BANNER_ADD">
# <p class="media_end_channel_banner_add">구독</p>
# <p class="media_end_channel_banner_txt"><span class="media_end_channel_banner_span"><strong>메인에서</strong> 바로 보는 언론사 편집 뉴스 지금 바로 구독해보세요!</span></p>
# </div>
# <div class="media_end_channel_banner_body _after _CHANNEL_BANNER_REMOVE is_hidden">
# <p class="media_end_channel_banner_add is_disabled">구독중</p>
# <p class="media_end_channel_banner_txt"><span class="media_end_channel_banner_span"><strong>메인에서</strong> 바로 보는 언론사 편집 뉴스 지금 바로 확인해보세요!</span></p>
# </div>
# </a>
# </div>
# </div>
# <div id="channelBannerRecommendList"></div>
# <script class="_CHANNEL_BANNER_RECOMMEND_LIST" type="x-tmpl-mustache">
# 	<div class="office_preference _CHANNEL_BANNER_RECOMMEND_LIST_WRAP">
# 	<div class="ofpr_recommend">
# 		<div class="ofpr_recommend_inner">
# 			<div class="ofpr_more_link">
# 				<h4 class="ofpr_tit">관심있는 언론사를 추가 구독해 보세요!</h4>
# 			</div>
# 			<ul class="ofpr_channel">
# 				{{#recommendList}}
# 				<li class="ofpr_item">
# 					<a href="#" class="ofpr_a _ALL_OFFICES_ITEM" data-officeId="{{officeId}}" data-officename="{{name}}" data-logo="{{logo}}" role="checkbox" aria-checked="false" data-clk-add="chwith" data-clk-remove="chwithno" data-target="_CHANNEL_BANNER_RECOMMEND_LIST_WRAP">
# 						<div class="ofpr_thumb"><img src="{{logo}}" class="ofpr_m" alt="" onerror="this.outerHTML='<span class=&quot;noimage&quot;></span>'"></div>
# 						<div class="ofpr_text">{{name}}</div>
# 						<span class="ofpr_badge">언론사 추가</span>
# 					</a>
# 				</li>
# 				{{/recommendList}}
# 			</ul>
# 			<div class="ofpr_btn_wrap">
# 				<div class="ofpr_btn_inner">
# 				<button type="button" class="ofpr_btn_more _ALL_OFFICE_LIST" data-clk="chwithall">언론사 전체보기</button>
# 				<button type="button" class="ofpr_btn_confirm _ALL_OFFICES_COMPLETE disabled" data-clk-disabled="chwithsetall" data-clk-enabled="chwithchoice" data-target="_CHANNEL_BANNER_RECOMMEND_LIST_WRAP">언론사 전체 선택</button>
# 				</div>
# 			</div>
# 			<button type="button" class="ofpr_recommend_close _TOGGLE" data-target="channelBannerRecommendList" data-clk="chclosing">닫기</button>
# 		</div>
# 	</div>
# 	</div>
# 	</script>
# </div>
# <div class="check_visible" id="frontDetect"></div>
# <div class="office_headline more_news optional_hidden pc_hidden _FLICKING_WRAP _OFFICE_HEADLINE _PERSIST_HEIGHT _PERSIST_META _TEMPLATE" data-count="3" data-flicking-nclk="false" data-grid-template-column-aside="" data-nclk-prefix="art" data-persist="5_officeHeadline" data-template-id="OFFICE_HEADLINE">
# <div class="ofhe_head">
# <div class="ofhe_head_inner">
# <h2 class="ofhe_head_title">
# <a class="ofhe_head_title_link" data-clk="art.pheadhome" href="https://media.naver.com/press/011">
# <em>서울경제</em> 헤드라인
# 					</a>
# </h2>
# </div>
# </div>
# <div class="ofhe_body flick">
# <div class="flick-container _FLICKING" style="height: 161px; opacity:0;">
# <div class="flick-panel">
# <ul class="ofhe_list">
# <li class="ofhe_item _LAZY_LOADING_WRAP" data-loading-error-allowed="true">
# <a class="ofhe_link _NLOG_IMPRESSION" data-clk="art.phead" data-imp-gdid="88000108_000000000000000004387299" data-imp-index="1" data-imp-url="https://n.news.naver.com/article/011/0004387299" href="/mnews/article/011/0004387299">
# <div class="ofhe_thumb _LAZY_LOADING_ERROR_HIDE">
# <div class="ofhe_image">
# <img alt="" class="_LAZY_LOADING" data-scroll="true" data-src="https://mimgnews.pstatic.net/image/origin/011/2024/09/02/4387299.jpg?type=nf336_206&amp;ut=20240902163413"/>
# </div>
# </div>
# <div class="ofhe_headline">대출 조이니 풍선효과…9억 이하 아파트 거래 비중 증가</div>
# <div class="ofhe_lede _LAZY_LOADING_ERROR_SHOW" style="display:none;">정부의 대출 규제 권고로 은행들이 주택담보대출 금리를 올리기 시작한 7월부터 9억 원 이하 아파트 거래 비중이 증가하고 있다. 대출이자 부담에 아파트 가격이 비교적 저렴한 노원·도봉·강북(노도강) 지역이나 소형 아파</div>
# </a>
# </li>
# <li class="ofhe_item _LAZY_LOADING_WRAP" data-loading-error-allowed="true">
# <a class="ofhe_link _NLOG_IMPRESSION" data-clk="art.phead" data-imp-gdid="88000108_000000000000000004387286" data-imp-index="2" data-imp-url="https://n.news.naver.com/article/011/0004387286" href="/mnews/article/011/0004387286">
# <div class="ofhe_thumb _LAZY_LOADING_ERROR_HIDE">
# <div class="ofhe_image">
# <img alt="" class="_LAZY_LOADING" data-scroll="true" data-src="https://mimgnews.pstatic.net/image/origin/011/2024/09/02/4387286.jpg?type=nf336_206&amp;ut=20240902154212"/>
# </div>
# </div>
# <div class="ofhe_headline">"100만원 상품권을 85만원에 산다고?"…할인율 15%에 접속 '폭주'</div>
# <div class="ofhe_lede _LAZY_LOADING_ERROR_SHOW" style="display:none;">100만원 상품권을 85만원에 살 수 있다고? 중소벤처기업부와 소상공인시장진흥공단이 추석을 앞두고 온누리상품권 특별할인 판매를 시작한다. 이번 특별할인을 통해 상품권 할인율이 최대 15%까지 확대되며, 구매 한도도 </div>
# </a>
# </li>
# </ul>
# </div>
# <div class="flick-panel">
# <ul class="ofhe_list">
# <li class="ofhe_item _LAZY_LOADING_WRAP" data-loading-error-allowed="true">
# <a class="ofhe_link _NLOG_IMPRESSION" data-clk="art.phead" data-imp-gdid="88000108_000000000000000004387302" data-imp-index="3" data-imp-url="https://n.news.naver.com/article/011/0004387302" href="/mnews/article/011/0004387302">
# <div class="ofhe_thumb _LAZY_LOADING_ERROR_HIDE">
# <div class="ofhe_image">
# <img alt="" class="_LAZY_LOADING" data-scroll="true" data-src="https://mimgnews.pstatic.net/image/origin/011/2024/09/02/4387302.jpg?type=nf336_206&amp;ut=20240902160509"/>
# </div>
# </div>
# <div class="ofhe_headline">文수사에 여야 대립 격화… 與 "직접 수사" 野 "정치보복"</div>
# <div class="ofhe_lede _LAZY_LOADING_ERROR_SHOW" style="display:none;">문재인 전 대통령의 사위였던 서 모 씨의 항공사 특혜 채용 의혹을 수사하는 검찰의 칼날이 문 전 대통령을 향하는 것을 두고 여야 공방이 거세지고 있다. 더불어민주당은 2일 문 전 대통령이 뇌물수수 혐의 피의자로 적시</div>
# </a>
# </li>
# <li class="ofhe_item _LAZY_LOADING_WRAP" data-loading-error-allowed="true">
# <a class="ofhe_link _NLOG_IMPRESSION" data-clk="art.phead" data-imp-gdid="88000108_000000000000000004387252" data-imp-index="4" data-imp-url="https://n.news.naver.com/article/011/0004387252" href="/mnews/article/011/0004387252">
# <div class="ofhe_thumb _LAZY_LOADING_ERROR_HIDE">
# <div class="ofhe_image">
# <img alt="" class="_LAZY_LOADING" data-scroll="true" data-src="https://mimgnews.pstatic.net/image/origin/011/2024/09/02/4387252.jpg?type=nf336_206&amp;ut=20240902150009"/>
# </div>
# </div>
# <div class="ofhe_headline">"직 걸고 가만 안두겠다" 자녀 학교 찾아간 현직 경찰관 '무혐의 처분', 왜?</div>
# <div class="ofhe_lede _LAZY_LOADING_ERROR_SHOW" style="display:none;">자녀가 재학 중인 학교를 찾아가 담임교사를 협박한 혐의를 받는 현직 경찰관이 경찰에서 무혐의 처분을 받았다. 경기 오산경찰서는 협박 혐의로 고발된 오산시의 모 중학교 학부모 A씨에 대해 지난달 말 불송치 결정을 내렸</div>
# </a>
# </li>
# </ul>
# </div>
# <div class="flick-panel">
# <ul class="ofhe_list">
# <li class="ofhe_item _LAZY_LOADING_WRAP" data-loading-error-allowed="true">
# <a class="ofhe_link _NLOG_IMPRESSION" data-clk="art.phead" data-imp-gdid="88000108_000000000000000004387171" data-imp-index="5" data-imp-url="https://n.news.naver.com/article/011/0004387171" href="/mnews/article/011/0004387171">
# <div class="ofhe_thumb _LAZY_LOADING_ERROR_HIDE">
# <div class="ofhe_image">
# <img alt="" class="_LAZY_LOADING" data-scroll="true" data-src="https://mimgnews.pstatic.net/image/origin/011/2024/09/02/4387171.jpg?type=nf336_206&amp;ut=20240902124513"/>
# </div>
# </div>
# <div class="ofhe_headline">"각방 쓰고 애는 안 낳아요" 이런 MZ부부 많더니 결국…아파트 구조까지 바꿨다는데 무슨 일?</div>
# <div class="ofhe_lede _LAZY_LOADING_ERROR_SHOW" style="display:none;">고령화, 1~2인 가구 증가 등 인구구조가 급변하면서 아파트 평면 설계에도 변화가 일기 시작했다. 4인 가족 등 중심의 설계에서 달라진 부부, 가족 관계 등을 반영해 자녀 드레스룸, ‘각방 부부’을 위한 침실 설계 </div>
# </a>
# </li>
# <li class="ofhe_item _LAZY_LOADING_WRAP" data-loading-error-allowed="true">
# <a class="ofhe_link _NLOG_IMPRESSION" data-clk="art.phead" data-imp-gdid="88000108_000000000000000004387267" data-imp-index="6" data-imp-url="https://n.news.naver.com/article/011/0004387267" href="/mnews/article/011/0004387267">
# <div class="ofhe_thumb _LAZY_LOADING_ERROR_HIDE">
# <div class="ofhe_image">
# <img alt="" class="_LAZY_LOADING" data-scroll="true" data-src="https://mimgnews.pstatic.net/image/origin/011/2024/09/02/4387267.jpg?type=nf336_206&amp;ut=20240902151808"/>
# </div>
# </div>
# <div class="ofhe_headline">"욜로 했다간 골로"…MZ세대, 이제는 "요노(YONO)"할래요</div>
# <div class="ofhe_lede _LAZY_LOADING_ERROR_SHOW" style="display:none;">불확실한 미래에 불안해 하는 대신 현재의 행복에 집중하자는 의미로 젊은층에서 큰 공감을 불러일으킨 ‘욜로(YOLO·You Live Only Once의 줄임말로 인생은 한 번 뿐이라는 뜻)’의 인기가 서서히 저물고 있</div>
# </a>
# </li>
# </ul>
# </div>
# </div>
# </div>
# <div class="ofhe_paginate pg">
# <div class="pg_num_area pg_num_area_v2">
# <button class="pg_btn_prev _FLICKING_PREV" type="button"><span class="blind">이전 뉴스들 보기</span></button>
# <div class="_FLICKING_INDICATOR" data-count="3"></div>
# <div class="pg_line"></div>
# <div class="pg_num pg_num">3</div>
# <button class="pg_btn_next _FLICKING_NEXT" type="button"><span class="blind">다음 뉴스들 보기</span></button>
# </div>
# </div>
# <script class="_FLICKING_INDICATOR_TEMPLATE _PC" type="x-tmpl-mustache">
# 	{{#selected}}
# 		<div class="pg_num pg_num_cur">{{number}}</div>
# 	{{/selected}}
# 	</script>
# </div>
# <script>
# 			window.__htExternalUrl = window.__htExternalUrl || {};
# 			window.__htExternalUrl["comment"] = "https://ssl.pstatic.net/static.cbox/js/cbox.core.js";
# 			window.__htCboxOption = {"htMessage":{"template":{"user":{"profile":{"help":{"last":{"help_desc":"최근 30일간 작성한 댓글의 정보를 요약해 보여줍니다. 작성대비 본인의 삭제비율<em>(본인삭제율)</em>과 작성글이 받은 피드백 중 공감비율<em>(받은공감률)</em>을 표기합니다. <br/>이때, 받은공감률은 댓글 삭제로 변동된 정보를 반영하지 않습니다."}},"title":"뉴스 댓글모음"},"header":{"help":{"content":"댓글목록을 공개한 사용자의 댓글모음이 제공됩니다. 나의 댓글 모음에서 다른 사람에게 공개 또는 비공개 설정을 할 수 있습니다. 제공되는 목록에 삭제댓글/답글은 포함하지 않습니다.","title":"뉴스댓글 도움말"}}},"social_login_message":"계정을 선택하시면 <span class=\"u_cbox_msg_point\">로그인&middot;계정인증</span>을 통해<br> 댓글을 남기실 수 있습니다.<br>뉴스서비스에서는 소셜 계정 사용이 불가하며<br>댓글모음만 확인하실 수 있습니다.","write_placeholder":"댓글을 입력해주세요","sort_favorite":"순공감순","duplicate_caution_link_address_pc":"https://news.naver.com/main/principle.naver","duplicate_caution_link_address_mobile":"https://m.news.naver.com/ombudsman/index?mode=rule&open=comment","duplicate_caution_link_title":"운영규정 자세히 알아보기","duplicate_caution_cont":"반복 등록이 계속될 경우 운영규정에 따라 <br>서비스 이용이 정지될 수 있습니다.","duplicate_caution_title":"동일 내용 댓글의 반복 등록이<br>확인되었습니다.","write_long_placeholder":"다양한 의견이 서로 존중될 수 있도록 다른 사람에게 불쾌감을 주는 욕설, 혐오, 비하의 표현이나 타인의 권리를 침해하는 내용은 주의해주세요.  모든 작성자는 <em class=\"u_cbox_guide_emphasis\">본인이 작성한 의견에 대해 법적 책임을 갖는다는 점</em> 유의하시기 바랍니다.","help_titles":["댓글이력공개안내","댓글노출정책"],"info_comment_off":"<em>서울경제</em> 댓글 정책에 따라<br>이 기사에서는 댓글을 제공하지 않습니다.","view_all":"댓글 더보기","help_contents":["작성자가 삭제한 댓글(작성자 삭제), 운영자가 삭제한 댓글(규정 미준수) 그리고 삭제되지 않은 현재 남은 댓글의 수와 이력을 투명하게 제공합니다.","순공감순은 공감수에서 비공감수를 뺀 수치가 많은 댓글입니다. 비정상적인 방법으로 공감수가 증가하는 경우 제외될 수 있습니다."],"reply_close":"답글 접기","list_empty":"등록된 댓글이 없습니다.","comment_link":"이 기사의 댓글 전체보기"},"stats":{"title":"댓글 작성 통계","view":"통계","fold":"접기","user_env_title":"어디에서 댓글을 썼을까요?"},"alert":{"max_length":"{0}자까지 입력할 수 있습니다.","login_require":"로그인을 하신 후 이용해 주시기 바랍니다.","min_length":"내용을 최소 {0}자 이상 입력해주세요."}},"nPageSize":20,"sObjectId":"news011,0004386530","sLikeItId":"ne_011_0004386530","sTicket":"news","nUserCommentReplyPageSize":10,"sAuthType":"naver","sTemplateId":"default_politics_m3","htErrorHandler":{"3003":"고객님께서는 운영원칙에서 제한하고 있는 글을 작성하셨기 때문에 글쓰기를 포함한 일부 활동이 일정 기간 제한되었습니다. 동일 내용 댓글의 반복작성이 확인된 경우 제한기간은 1일이며, 반복이 계속되면 기간이 연장될 수 있습니다.","3004":"고객님께서는 운영원칙에서 제한하고 있는 글을 다수 작성하셨기 때문에 글쓰기를 포함한 일부​ 활동이 일정 기간 제한되었습니다.","3005":"고객님의 IP는 운영원칙에서 제한하고 있는 글을 작성하셨기 때문에 글쓰기를 포함한 일부​ 활동이 제한되었습니다.","3006":"고객님께서는 운영원칙에서 제한하고 있는 글을 작성하셨기 때문에 무기한 글쓰기를 포함한 일부​ 활동이 제한되었습니다.","3011":"서울경제 댓글 정책에 따라 이 기사에서는 댓글을 제공하지 않습니다.","4004":"해당되는 댓글이 없습니다.","5003":"정상적으로 반영되지 않았습니다. 화면 새로고침 후 다시 시도해 주세요.","5006":"자신의 글에 공감 할 수 없습니다.","5008":"자신의 글에 비공감 할 수 없습니다.","5010":"댓글/답글은 60초 내에 한 개만 등록하실 수 있습니다.","5026":"공감/비공감은 최근 24시간내 50회까지 가능합니다.","5027":"공감/비공감은 10초 내에 한 번만 클릭하실 수 있습니다.","5029":"기사당 댓글은 3개, 답글은 10개까지 작성할 수 있습니다.","5080":"실명확인을 받지 않은 아이디는 가입 이후 7일이 지난 시점부터 댓글 활동이 가능합니다.","5091":"본인 확인이 되지 않은 계정입니다. 본인 확인 후 다시 시도해주세요."},"bSortCookie":true,"bMobile":false,"bShowReply":false,"bManager":false,"sDomain":"https://ssl.pstatic.net/static.cbox","sCountry":"KR","nUserCommentPageSize":20,"sLanguage":"ko","sDateFormat":"Y.m.d. H:i:s","sCommentNo":"","sPageType":"more","sHelp":"down","sSort":"FAVORITE","sApiDomain":"https://apis.naver.com/commentBox/cbox5","nFollowSize":5,"nFeedPageSize":50,"bIncludeAllComments":true,"sCountType":"comment","aFormation":["count","graph","write","notice","follow","list","page"],"bByCountry":false,"bUseAgo":false,"nReplyPageSize":20,"sCssId":"news_w","aSortTypes":["FAVORITE","NEW","RELATIVE","REPLY","OLD"]};
# 			window.__htCboxOption["bLogin"] = isLogin;
# 			window.__htCboxOption["bMobile"] = false;
# 			window.__htCboxOption["sHighlightColor"] = "rgba(124, 255, 182, 0.06)";
# 			window.__htCboxOption["vViewAllHandler"] = function() {
# 				window.location.href = "/mnews/article/comment/011/0004386530";
# 			};
# 		</script>
# <div class="changecmt" id="_COMMENT_NOTICE" style="display:none;">
# <p class="changecmt_p _LAZY_LOADING_WRAP">
# <span class="changecmt_image _LAZY_LOADING_ERROR_HIDE"><img alt="" class="changecmt_img _LAZY_LOADING" data-src="https://mimgnews.pstatic.net/image/upload/office_logo/011/2022/07/29/logo_011_57_20220729150242.jpg"/></span><em>서울경제</em>가 이 기사의 댓글 정책을 결정합니다.
# 					<span class="changecmt_info">
# <button class="changecmt_info_icon _layer_notice_btn _TOGGLE" data-classvalue="is_hidden" data-target="_COMMENT_NOTICE_INFO_LAYER" type="button">안내</button><span class="changecmt_layer _layer_notice is_hidden" id="_COMMENT_NOTICE_INFO_LAYER">
# <strong class="changecmt_info_title"><span class="changecmt_ico_help"></span>댓글 정책 언론사별 선택제</strong>
# <span class="changecmt_info_txt">섹션별로 기사의 댓글 제공여부와 정렬방식을 <br/>언론사가 직접 결정합니다. 기사 섹션 정보가<br/>정치/선거를 포함하는 경우 정치/선거섹션 정책이<br/>적용됩니다. 단, 운영규정에 따른<br/>삭제나 이용제한 조치는 네이버가 직접<br/>수행합니다.</span>
# <button class="changecmt_btn_info_close _close_layer _TOGGLE" data-classvalue="is_hidden" data-target="_COMMENT_NOTICE_INFO_LAYER">레이어 닫기</button>
# </span>
# </span>
# </p>
# </div>
# <div class="_COMMENT _COMMENT_HIDE" id="cbox_module">
# </div><div class="rankingnews mobile_hidden is_hidden _TEMPLATE" data-grid-template-column-aside="true" data-template-id="OFFICE_HEADLINE_FLAT">
# <div class="ra_head">
# <strong class="ra_title"><em class="ra_highlight">서울경제</em> 헤드라인</strong>
# <a class="media_more" data-clk="pheadhome" href="https://media.naver.com/press/011"><span class="blind">더보기</span></a>
# </div>
# <div class="ra_area">
# <div class="flick">
# <div class="flick-container">
# <div class="flick-panel">
# <ul class="ranking_list">
# <li class="rl_item _LAZY_LOADING_WRAP" data-loading-error-allowed="true">
# <a class="rl_link_end _NLOG_IMPRESSION" data-clk="art.phead" data-imp-gdid="88000108_000000000000000004387299" data-imp-index="1" data-imp-url="https://n.news.naver.com/article/011/0004387299" href="/mnews/article/011/0004387299">
# <div class="rl_content">
# <p class="rl_txt">대출 조이니 풍선효과…9억 이하 아파트 거래 비중 증가</p>
# <div class="rl_time">35분전</div>
# </div>
# <div class="rl_img _LAZY_LOADING_ERROR_HIDE">
# <div class="rl_border">
# <img alt="" class="_LAZY_LOADING" data-scroll="true" data-src="https://mimgnews.pstatic.net/image/origin/011/2024/09/02/4387299.jpg?type=nf190_130&amp;ut=20240902163413" height="65" width="95"/>
# </div>
# </div>
# </a>
# </li>
# <li class="rl_item _LAZY_LOADING_WRAP" data-loading-error-allowed="true">
# <a class="rl_link_end _NLOG_IMPRESSION" data-clk="art.phead" data-imp-gdid="88000108_000000000000000004387286" data-imp-index="2" data-imp-url="https://n.news.naver.com/article/011/0004387286" href="/mnews/article/011/0004387286">
# <div class="rl_content">
# <p class="rl_txt">"100만원 상품권을 85만원에 산다고?"…할인율 15%에 접속 '폭주'</p>
# <div class="rl_time">55분전</div>
# </div>
# <div class="rl_img _LAZY_LOADING_ERROR_HIDE">
# <div class="rl_border">
# <img alt="" class="_LAZY_LOADING" data-scroll="true" data-src="https://mimgnews.pstatic.net/image/origin/011/2024/09/02/4387286.jpg?type=nf190_130&amp;ut=20240902154212" height="65" width="95"/>
# </div>
# </div>
# </a>
# </li>
# <li class="rl_item _LAZY_LOADING_WRAP" data-loading-error-allowed="true">
# <a class="rl_link_end _NLOG_IMPRESSION" data-clk="art.phead" data-imp-gdid="88000108_000000000000000004387302" data-imp-index="3" data-imp-url="https://n.news.naver.com/article/011/0004387302" href="/mnews/article/011/0004387302">
# <div class="rl_content">
# <p class="rl_txt">文수사에 여야 대립 격화… 與 "직접 수사" 野 "정치보복"</p>
# <div class="rl_time">32분전</div>
# </div>
# <div class="rl_img _LAZY_LOADING_ERROR_HIDE">
# <div class="rl_border">
# <img alt="" class="_LAZY_LOADING" data-scroll="true" data-src="https://mimgnews.pstatic.net/image/origin/011/2024/09/02/4387302.jpg?type=nf190_130&amp;ut=20240902160509" height="65" width="95"/>
# </div>
# </div>
# </a>
# </li>
# <li class="rl_item _LAZY_LOADING_WRAP" data-loading-error-allowed="true">
# <a class="rl_link_end _NLOG_IMPRESSION" data-clk="art.phead" data-imp-gdid="88000108_000000000000000004387252" data-imp-index="4" data-imp-url="https://n.news.naver.com/article/011/0004387252" href="/mnews/article/011/0004387252">
# <div class="rl_content">
# <p class="rl_txt">"직 걸고 가만 안두겠다" 자녀 학교 찾아간 현직 경찰관 '무혐의 처분', 왜?</p>
# <div class="rl_time">1시간전</div>
# </div>
# <div class="rl_img _LAZY_LOADING_ERROR_HIDE">
# <div class="rl_border">
# <img alt="" class="_LAZY_LOADING" data-scroll="true" data-src="https://mimgnews.pstatic.net/image/origin/011/2024/09/02/4387252.jpg?type=nf190_130&amp;ut=20240902150009" height="65" width="95"/>
# </div>
# </div>
# </a>
# </li>
# <li class="rl_item _LAZY_LOADING_WRAP" data-loading-error-allowed="true">
# <a class="rl_link_end _NLOG_IMPRESSION" data-clk="art.phead" data-imp-gdid="88000108_000000000000000004387171" data-imp-index="5" data-imp-url="https://n.news.naver.com/article/011/0004387171" href="/mnews/article/011/0004387171">
# <div class="rl_content">
# <p class="rl_txt">"각방 쓰고 애는 안 낳아요" 이런 MZ부부 많더니 결국…아파트 구조까지 바꿨다는데 무슨 일?</p>
# <div class="rl_time">3시간전</div>
# </div>
# <div class="rl_img _LAZY_LOADING_ERROR_HIDE">
# <div class="rl_border">
# <img alt="" class="_LAZY_LOADING" data-scroll="true" data-src="https://mimgnews.pstatic.net/image/origin/011/2024/09/02/4387171.jpg?type=nf190_130&amp;ut=20240902124513" height="65" width="95"/>
# </div>
# </div>
# </a>
# </li>
# <li class="rl_item _LAZY_LOADING_WRAP" data-loading-error-allowed="true">
# <a class="rl_link_end _NLOG_IMPRESSION" data-clk="art.phead" data-imp-gdid="88000108_000000000000000004387267" data-imp-index="6" data-imp-url="https://n.news.naver.com/article/011/0004387267" href="/mnews/article/011/0004387267">
# <div class="rl_content">
# <p class="rl_txt">"욜로 했다간 골로"…MZ세대, 이제는 "요노(YONO)"할래요</p>
# <div class="rl_time">1시간전</div>
# </div>
# <div class="rl_img _LAZY_LOADING_ERROR_HIDE">
# <div class="rl_border">
# <img alt="" class="_LAZY_LOADING" data-scroll="true" data-src="https://mimgnews.pstatic.net/image/origin/011/2024/09/02/4387267.jpg?type=nf190_130&amp;ut=20240902151808" height="65" width="95"/>
# </div>
# </div>
# </a>
# </li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="r_group_comp ad_box _da_banner is_border_none mobile_hidden" data-grid-template-column-aside="true">
# <div class="ad_area _AD_WRAP _PERSIST_HEIGHT" data-article="false" data-mobileonly="false" data-persist="2_ad" data-sync="true" data-unitid="p_news_sidebox" id="nmap_c_011_0004386530_100_2"></div>
# </div>
# <div class="col2_banner mobile_hidden is_hidden _LAZY_LOADING_WRAP" data-grid-template-column-aside="true">
# <div class="col2_banner_inner _LAZY_LOADING_ERROR_HIDE">
# <a class="col2_banner_link" data-clk="asidebanner1" href="https://media.naver.com/algorithm">
# <img alt="네이버 AI 뉴스 알고리즘" class="_LAZY_LOADING _LAZY_LOADING_INIT_HIDE" data-src="https://imgnews.pstatic.net/image/upload/item/2023/07/06/183901500_banner_AI.png" height="80" style="display: none;" width="300"/>
# <div class="blind">
# <strong>네이버 AI 뉴스 알고리즘</strong>
# <p>뉴스 추천 알고리즘이 궁금하다면?</p>
# </div>
# </a>
# </div>
# </div>
# <div class="rankingnews optional_hidden is_hidden _FLICKING_WRAP _OFFICE_RANKING_ALL _PERSIST_META _TEMPLATE" data-aggregation-end="" data-aggregation-start="" data-count="2" data-flicking-disable="" data-flicking-init-tab-index="" data-flicking-nclk="true" data-grid-template-column-aside="true" data-nclk-prefix="ark" data-persist="5_officeRankingAll" data-persist-origin-content="true" data-template-id="RANKING_NEWS_OFFICE">
# <div class="ra_head">
# <strong class="ra_title"><em class="ra_highlight">서울경제</em> 랭킹 뉴스</strong>
# <span class="ra_time _AGGREGATION_TEXT_LIST">오후 3시~4시까지 집계한 결과입니다.</span>
# <span class="ra_time _AGGREGATION_TEXT_LIST" style="display:none;">오후 1시~4시까지 집계한 결과입니다.</span>
# <a class="media_more _MORE_URL_LIST" data-clk="ark.renwsmore" href="https://media.naver.com/press/011/ranking"><span class="blind">더보기</span></a>
# <a class="media_more _MORE_URL_LIST" data-clk="ark.cmtnwsmore" href="https://media.naver.com/press/011/ranking?type=comment" style="display:none;"><span class="blind">더보기</span></a>
# </div>
# <div class="ra_area">
# <div class="ra_tab">
# <ul class="ra_tab_list">
# <li class="ra_tab_item _FLICKING_TAB on" data-aggregation-text-visible="" data-index="0" data-random="false" data-subtab-count="1" style="opacity:0;">
# <a class="ra_tab_a" data-clk="ark.renwstab" href="#">많이 본</a>
# </li>
# <li class="ra_tab_item _FLICKING_TAB" data-aggregation-text-visible="" data-index="1" data-random="false" data-subtab-count="1" style="opacity:0;">
# <a class="ra_tab_a" data-clk="ark.cmtnwstab" href="#">댓글 많은</a>
# </li>
# </ul>
# </div>
# <div class="flick" style="height:442px;">
# <div class="flick-container _FLICKING" style="height:442px; opacity:0;">
# <div class="flick-panel" data-index="0" data-subtab-count="1">
# <ul class="ranking_list _FLICKING_CONTENT" data-index="0" style="margin-top: 0;">
# <li class="rl_item _LAZY_LOADING_WRAP" data-loading-error-allowed="true">
# <div class="rl_link_end">
# <i class="rl_ranking">1</i>
# <div class="rl_content">
# <p class="rl_txt">"각방 쓰고 애는 안 낳아요" 이런 MZ부부 많더니 결국…아파트 구조까지 바꿨다는데 무슨 일?</p>
# <div class="rl_time">3시간전</div>
# </div>
# <div class="rl_img _LAZY_LOADING_WRAP _LAZY_LOADING_ERROR_HIDE">
# <div class="rl_border">
# <img alt="" class="_LAZY_LOADING" data-scroll="true" data-src="https://mimgnews.pstatic.net/image/origin/011/2024/09/02/4387171.jpg?type=nf190_130&amp;ut=1725248713000" height="65" width="95"/>
# </div>
# </div>
# <a class="rl_coverlink _NLOG_IMPRESSION" data-clk="ark.renws" data-imp-gdid="" data-imp-index="1" data-imp-url="https://n.news.naver.com/mnews/ranking/article/011/0004387171?ntype=RANKING" href="/mnews/ranking/article/011/0004387171?ntype=RANKING">
# <span class="blind">더보기</span>
# </a>
# </div>
# </li>
# <li class="rl_item _LAZY_LOADING_WRAP" data-loading-error-allowed="true">
# <div class="rl_link_end">
# <i class="rl_ranking">2</i>
# <div class="rl_content">
# <p class="rl_txt">"직 걸고 가만 안두겠다" 자녀 학교 찾아간 현직 경찰관 '무혐의 처분', 왜?</p>
# <div class="rl_time">1시간전</div>
# </div>
# <div class="rl_img _LAZY_LOADING_WRAP _LAZY_LOADING_ERROR_HIDE">
# <div class="rl_border">
# <img alt="" class="_LAZY_LOADING" data-scroll="true" data-src="https://mimgnews.pstatic.net/image/origin/011/2024/09/02/4387252.jpg?type=nf190_130&amp;ut=1725256809000" height="65" width="95"/>
# </div>
# </div>
# <a class="rl_coverlink _NLOG_IMPRESSION" data-clk="ark.renws" data-imp-gdid="" data-imp-index="2" data-imp-url="https://n.news.naver.com/mnews/ranking/article/011/0004387252?ntype=RANKING" href="/mnews/ranking/article/011/0004387252?ntype=RANKING">
# <span class="blind">더보기</span>
# </a>
# </div>
# </li>
# <li class="rl_item _LAZY_LOADING_WRAP" data-loading-error-allowed="true">
# <div class="rl_link_end">
# <i class="rl_ranking">3</i>
# <div class="rl_content">
# <p class="rl_txt">"집 있으면 못 내 드립니다" 9일부터 대출 퇴짜 놓는 이 은행</p>
# <div class="rl_time">10시간전</div>
# </div>
# <div class="rl_img _LAZY_LOADING_WRAP _LAZY_LOADING_ERROR_HIDE">
# <div class="rl_border">
# <img alt="" class="_LAZY_LOADING" data-scroll="true" data-src="https://mimgnews.pstatic.net/image/origin/011/2024/09/02/4386960.jpg?type=nf190_130&amp;ut=1725224477000" height="65" width="95"/>
# </div>
# </div>
# <a class="rl_coverlink _NLOG_IMPRESSION" data-clk="ark.renws" data-imp-gdid="" data-imp-index="3" data-imp-url="https://n.news.naver.com/mnews/ranking/article/011/0004386960?ntype=RANKING" href="/mnews/ranking/article/011/0004386960?ntype=RANKING">
# <span class="blind">더보기</span>
# </a>
# </div>
# </li>
# <li class="rl_item _LAZY_LOADING_WRAP" data-loading-error-allowed="true">
# <div class="rl_link_end">
# <i class="rl_ranking">4</i>
# <div class="rl_content">
# <p class="rl_txt">정부 "4일부터 응급실에 군의관 배치…9일부터는 235명 파견"</p>
# <div class="rl_time">1시간전</div>
# </div>
# <div class="rl_img _LAZY_LOADING_WRAP _LAZY_LOADING_ERROR_HIDE">
# <div class="rl_border">
# <img alt="" class="_LAZY_LOADING" data-scroll="true" data-src="https://mimgnews.pstatic.net/image/origin/011/2024/09/02/4387254.jpg?type=nf190_130&amp;ut=1725257172000" height="65" width="95"/>
# </div>
# </div>
# <a class="rl_coverlink _NLOG_IMPRESSION" data-clk="ark.renws" data-imp-gdid="" data-imp-index="4" data-imp-url="https://n.news.naver.com/mnews/ranking/article/011/0004387254?ntype=RANKING" href="/mnews/ranking/article/011/0004387254?ntype=RANKING">
# <span class="blind">더보기</span>
# </a>
# </div>
# </li>
# <li class="rl_item _LAZY_LOADING_WRAP" data-loading-error-allowed="true">
# <div class="rl_link_end">
# <i class="rl_ranking">5</i>
# <div class="rl_content">
# <p class="rl_txt">"욜로 했다간 골로"…MZ세대, 이제는 "요노(YONO)"할래요</p>
# <div class="rl_time">1시간전</div>
# </div>
# <div class="rl_img _LAZY_LOADING_WRAP _LAZY_LOADING_ERROR_HIDE">
# <div class="rl_border">
# <img alt="" class="_LAZY_LOADING" data-scroll="true" data-src="https://mimgnews.pstatic.net/image/origin/011/2024/09/02/4387267.jpg?type=nf190_130&amp;ut=1725257888000" height="65" width="95"/>
# </div>
# </div>
# <a class="rl_coverlink _NLOG_IMPRESSION" data-clk="ark.renws" data-imp-gdid="" data-imp-index="5" data-imp-url="https://n.news.naver.com/mnews/ranking/article/011/0004387267?ntype=RANKING" href="/mnews/ranking/article/011/0004387267?ntype=RANKING">
# <span class="blind">더보기</span>
# </a>
# </div>
# </li>
# </ul>
# </div>
# <div class="flick-panel" data-index="1" data-subtab-count="1">
# <ul class="ranking_list _FLICKING_CONTENT" data-index="0" style="margin-top: 0;">
# <li class="rl_item _LAZY_LOADING_WRAP" data-loading-error-allowed="true">
# <div class="rl_link_end">
# <i class="rl_ranking">1</i>
# <div class="rl_content">
# <p class="rl_txt">"각방 쓰고 애는 안 낳아요" 이런 MZ부부 많더니 결국…아파트 구조까지 바꿨다는데 무슨 일?</p>
# <div class="rl_time">3시간전</div>
# </div>
# <div class="rl_img _LAZY_LOADING_WRAP _LAZY_LOADING_ERROR_HIDE">
# <div class="rl_border">
# <img alt="" class="_LAZY_LOADING" data-scroll="true" data-src="https://mimgnews.pstatic.net/image/origin/011/2024/09/02/4387171.jpg?type=nf190_130&amp;ut=1725248713000" height="65" width="95"/>
# </div>
# </div>
# <a class="rl_coverlink _NLOG_IMPRESSION" data-clk="ark.cmtnws" data-imp-gdid="" data-imp-index="1" data-imp-url="https://n.news.naver.com/mnews/ranking/article/011/0004387171?ntype=RANKING" href="/mnews/ranking/article/011/0004387171?ntype=RANKING">
# <span class="blind">더보기</span>
# </a>
# </div>
# </li>
# <li class="rl_item _LAZY_LOADING_WRAP" data-loading-error-allowed="true">
# <div class="rl_link_end">
# <i class="rl_ranking">2</i>
# <div class="rl_content">
# <p class="rl_txt">정부 "4일부터 응급실에 군의관 배치…9일부터는 235명 파견"</p>
# <div class="rl_time">1시간전</div>
# </div>
# <div class="rl_img _LAZY_LOADING_WRAP _LAZY_LOADING_ERROR_HIDE">
# <div class="rl_border">
# <img alt="" class="_LAZY_LOADING" data-scroll="true" data-src="https://mimgnews.pstatic.net/image/origin/011/2024/09/02/4387254.jpg?type=nf190_130&amp;ut=1725257172000" height="65" width="95"/>
# </div>
# </div>
# <a class="rl_coverlink _NLOG_IMPRESSION" data-clk="ark.cmtnws" data-imp-gdid="" data-imp-index="2" data-imp-url="https://n.news.naver.com/mnews/ranking/article/011/0004387254?ntype=RANKING" href="/mnews/ranking/article/011/0004387254?ntype=RANKING">
# <span class="blind">더보기</span>
# </a>
# </div>
# </li>
# <li class="rl_item _LAZY_LOADING_WRAP" data-loading-error-allowed="true">
# <div class="rl_link_end">
# <i class="rl_ranking">3</i>
# <div class="rl_content">
# <p class="rl_txt">[속보] 경찰, 처음으로 '텔레그램 법인' 내사…딥페이크 성범죄 방조 혐의</p>
# <div class="rl_time">4시간전</div>
# </div>
# <div class="rl_img _LAZY_LOADING_WRAP _LAZY_LOADING_ERROR_HIDE">
# <div class="rl_border">
# <img alt="" class="_LAZY_LOADING" data-scroll="true" data-src="https://mimgnews.pstatic.net/image/origin/011/2024/09/02/4387169.jpg?type=nf190_130&amp;ut=1725247390000" height="65" width="95"/>
# </div>
# </div>
# <a class="rl_coverlink _NLOG_IMPRESSION" data-clk="ark.cmtnws" data-imp-gdid="" data-imp-index="3" data-imp-url="https://n.news.naver.com/mnews/ranking/article/011/0004387169?ntype=RANKING" href="/mnews/ranking/article/011/0004387169?ntype=RANKING">
# <span class="blind">더보기</span>
# </a>
# </div>
# </li>
# <li class="rl_item _LAZY_LOADING_WRAP" data-loading-error-allowed="true">
# <div class="rl_link_end">
# <i class="rl_ranking">4</i>
# <div class="rl_content">
# <p class="rl_txt">힘 못쓴 국정브리핑…尹지지율 30％ 깨져</p>
# <div class="rl_time">1시간전</div>
# </div>
# <div class="rl_img _LAZY_LOADING_WRAP _LAZY_LOADING_ERROR_HIDE">
# <div class="rl_border">
# <img alt="" class="_LAZY_LOADING" data-scroll="true" data-src="https://mimgnews.pstatic.net/image/origin/011/2024/09/02/4387245.jpg?type=nf190_130&amp;ut=1725255974000" height="65" width="95"/>
# </div>
# </div>
# <a class="rl_coverlink _NLOG_IMPRESSION" data-clk="ark.cmtnws" data-imp-gdid="" data-imp-index="4" data-imp-url="https://n.news.naver.com/mnews/ranking/article/011/0004387245?ntype=RANKING" href="/mnews/ranking/article/011/0004387245?ntype=RANKING">
# <span class="blind">더보기</span>
# </a>
# </div>
# </li>
# <li class="rl_item _LAZY_LOADING_WRAP" data-loading-error-allowed="true">
# <div class="rl_link_end">
# <i class="rl_ranking">5</i>
# <div class="rl_content">
# <p class="rl_txt">尹 "추석연휴 의료 특별대책에 만전 기하라"</p>
# <div class="rl_time">3시간전</div>
# </div>
# <div class="rl_img _LAZY_LOADING_WRAP _LAZY_LOADING_ERROR_HIDE">
# <div class="rl_border">
# <img alt="" class="_LAZY_LOADING" data-scroll="true" data-src="https://mimgnews.pstatic.net/image/origin/011/2024/09/02/4387173.jpg?type=nf190_130&amp;ut=1725249731000" height="65" width="95"/>
# </div>
# </div>
# <a class="rl_coverlink _NLOG_IMPRESSION" data-clk="ark.cmtnws" data-imp-gdid="" data-imp-index="5" data-imp-url="https://n.news.naver.com/mnews/ranking/article/011/0004387173?ntype=RANKING" href="/mnews/ranking/article/011/0004387173?ntype=RANKING">
# <span class="blind">더보기</span>
# </a>
# </div>
# </li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="_MY_CHANNEL_OFFICE_WRAP pc_hidden" data-grid-template-column-aside="true">
# </div> <div class="rankingnews as_type_subscribe optional_hidden is_hidden _FLICKING_WRAP _OFFICE_RANKING_ALL _PERSIST_META _PERSIST_CONTENT _TEMPLATE" data-aggregation-end="" data-aggregation-start="" data-count="2" data-flicking-disable="" data-flicking-init-tab-index="0" data-flicking-nclk="true" data-grid-template-column-aside="true" data-nclk-prefix="arwj" data-persist="6_officeRankingAll" data-persist-origin-content="true" data-template-id="ARTICLE_NEXT_JOURNALIST">
# <div class="ra_head">
# <strong class="ra_title"><em class="ra_highlight"></em> 함께 볼만한 기자</strong>
# <button class="help_button _TOGGLE" data-clk="arwj.infor" data-target="ARTICLE_NEXT_JOURNALIST" type="button"><span class="blind">안내</span></button>
# <div class="help_layer" id="ARTICLE_NEXT_JOURNALIST" style="display: none;">
# <p class="help_layer_text">최근 일주일 이내 업데이트된 기자 중에서 무작위 순서로 노출합니다.</p>
# <button class="help_layer_close _TOGGLE" data-clk="arwj.infor" data-target="ARTICLE_NEXT_JOURNALIST" type="button">닫기</button>
# </div>
# </div>
# <div class="ra_area">
# <div class="ra_tab">
# <ul class="ra_tab_list">
# <li class="ra_tab_item _FLICKING_TAB on" data-aggregation-text-visible="" data-index="0" data-random="false" data-subtab-count="5" style="opacity:0;">
# <a class="ra_tab_a" data-clk="arwj.similartab" href="#">비슷한 주제</a>
# </li>
# <li class="ra_tab_item _FLICKING_TAB" data-aggregation-text-visible="" data-index="1" data-random="false" data-subtab-count="5" style="opacity:0;">
# <a class="ra_tab_a" data-clk="arwj.risetab" href="#">구독이 늘어난</a>
# </li>
# </ul>
# </div>
# <div class="flick" style="height:442px;">
# <div class="flick-container _FLICKING" style="height:442px; opacity:0;">
# <div class="flick-panel" data-index="0" data-subtab-count="5">
# <ul class="ranking_list _FLICKING_CONTENT" data-index="0" style="margin-top: 0;">
# <li class="rl_item _LAZY_LOADING_WRAP" data-loading-error-allowed="true">
# <div class="rl_subscribe_end _SUBSCRIBE_ELE _LAZY_LOADING_WRAP" data-subscribe-type="JOURNALIST">
# <a class="rl_subscribe_thumb _LAZY_LOADING_ERROR_HIDE" data-clk="arwj.art" href="https://media.naver.com/journalist/448/74200">
# <img alt="윤동빈 기자" class="_LAZY_LOADING _LAZY_LOADING_INIT_HIDE" data-scroll="true" data-src="https://mimgnews.pstatic.net/image/upload/journalist/2020/06/12/y.jpg?type=nf112_112" height="18" style="display: none;" width="18"/>
# </a>
# <div class="rl_subscribe_name">
# <a data-clk="arwj.art" href="https://media.naver.com/journalist/448/74200">윤동빈 기자</a>
# </div>
# <div class="subscribe_wrap">
# <button class="subscribe _SUBSCRIBE" data-channelkey="JOURNALIST_74200" data-clk="arwj.subp" data-close-layer-delay-ms="3000" data-open-layer-target-id="_SUBSCRIBE_GUIDE_xr7gd" type="button"><span class="subscribe_ico"><span>구독</span></span></button>
# <button class="subscribe on _UNSUBSCRIBE" data-channelkey="JOURNALIST_74200" data-clk="arwj.subc" data-messagevalue="윤동빈" data-type="journalist" style="display: none;" type="button"><span class="subscribe_ico"><span>구독중</span></span></button>
# <div class="subscribe_guide _OTHER_OFFICE_SUBSCRIBE_GUIDE_LAYER" id="_SUBSCRIBE_GUIDE_xr7gd" style="display: none;">
# <p class="subscribe_guide_em">구독해주셔서 감사합니다</p>
# <a class="_MOVE_TO_NEWS" href="#">
# <p class="subscribe_guide_p">윤동빈 기자의 기사는<br/>언론사별에서 볼 수 있습니다</p>
# </a>
# <a class="subscribe_guide_close _CLOSE" data-target="._OTHER_OFFICE_SUBSCRIBE_GUIDE_LAYER" href="#">닫기</a>
# <div class="subscribe_guide_footer _LAZY_LOADING_WRAP">
# <div class="subscribe_footer_thumb _LAZY_LOADING_ERROR_HIDE">
# <img alt="TV조선" class="subscribe_footer_logo _LAZY_LOADING _LAZY_LOADING_INIT_HIDE" data-scroll="true" data-src="https://mimgnews.pstatic.net/image/upload/office_logo/448/2018/08/30/logo_448_18_20180830112530.png" height="18" style="display: none;" width="18"/>
# </div>
# <div class="subscribe_footer_text _OTHER_OFFICE_CHANNEL_SUBSCRIBE_WRAP">
# <div class="subscribe_footer_text_inner _OTHER_OFFICE_CHANNEL_SUBSCRIBE_BUTTON_WRAP">
# <small class="subscribe_footer_desc">언론사도 함께 구독해 보세요.</small>
# <div class="subscribe_guide_btn_wrapper">
# <button class="subscribe _CHANNEL_ADD _OTHER_OFFICE_CHANNEL_SUBSCRIBE_BUTTON" data-clk-add="arwj.press" data-oid="448" data-text="구독" type="button">
# 																			구독
# 																		</button>
# </div>
# </div>
# <div class="subscribe_footer_text_inner _OTHER_OFFICE_CHANNEL_SUBSCRIBE_FINISH_BUTTON_WRAP" style="display: none;">
# <a class="subscribe_footer_go" href="https://media.naver.com/press/448">
# 																		언론사를 함께 구독중입니다.
# 																	</a>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="rl_link_end">
# <div class="rl_content">
# <p class="rl_txt">'기밀유출' 정보사 7년간 외부감사 없었다…文정부의 기무사 훈령 개정 때문</p>
# <span class="rl_press">TV조선</span>
# <div class="rl_time">5시간전</div>
# </div>
# <div class="rl_img _LAZY_LOADING_WRAP _LAZY_LOADING_ERROR_HIDE">
# <div class="rl_border">
# <img alt="" class="_LAZY_LOADING" data-scroll="true" data-src="https://mimgnews.pstatic.net/image/origin/448/2024/09/02/475147.jpg?type=nf190_130&amp;ut=1725244298000" height="65" width="95"/>
# </div>
# </div>
# <a class="rl_coverlink" data-clk="arwj.art" href="https://media.naver.com/journalist/448/74200">
# <span class="blind">더보기</span>
# </a>
# </div>
# </li>
# <li class="rl_item _LAZY_LOADING_WRAP" data-loading-error-allowed="true">
# <div class="rl_subscribe_end _SUBSCRIBE_ELE _LAZY_LOADING_WRAP" data-subscribe-type="JOURNALIST">
# <a class="rl_subscribe_thumb _LAZY_LOADING_ERROR_HIDE" data-clk="arwj.art" href="https://media.naver.com/journalist/006/31569">
# <img alt="조현호 기자" class="_LAZY_LOADING _LAZY_LOADING_INIT_HIDE" data-scroll="true" data-src="https://mimgnews.pstatic.net/image/upload/journalist/2017/12/06/%EC%A1%B0%ED%98%84%ED%98%B8+%EA%B8%B0%EC%9E%90.jpg?type=nf112_112" height="18" style="display: none;" width="18"/>
# </a>
# <div class="rl_subscribe_name">
# <a data-clk="arwj.art" href="https://media.naver.com/journalist/006/31569">조현호 기자</a>
# </div>
# <div class="subscribe_wrap">
# <button class="subscribe _SUBSCRIBE" data-channelkey="JOURNALIST_31569" data-clk="arwj.subp" data-close-layer-delay-ms="3000" data-open-layer-target-id="_SUBSCRIBE_GUIDE_f6eqt" type="button"><span class="subscribe_ico"><span>구독</span></span></button>
# <button class="subscribe on _UNSUBSCRIBE" data-channelkey="JOURNALIST_31569" data-clk="arwj.subc" data-messagevalue="조현호" data-type="journalist" style="display: none;" type="button"><span class="subscribe_ico"><span>구독중</span></span></button>
# <div class="subscribe_guide _OTHER_OFFICE_SUBSCRIBE_GUIDE_LAYER" id="_SUBSCRIBE_GUIDE_f6eqt" style="display: none;">
# <p class="subscribe_guide_em">구독해주셔서 감사합니다</p>
# <a class="_MOVE_TO_NEWS" href="#">
# <p class="subscribe_guide_p">조현호 기자의 기사는<br/>언론사별에서 볼 수 있습니다</p>
# </a>
# <a class="subscribe_guide_close _CLOSE" data-target="._OTHER_OFFICE_SUBSCRIBE_GUIDE_LAYER" href="#">닫기</a>
# <div class="subscribe_guide_footer _LAZY_LOADING_WRAP">
# <div class="subscribe_footer_thumb _LAZY_LOADING_ERROR_HIDE">
# <img alt="미디어오늘" class="subscribe_footer_logo _LAZY_LOADING _LAZY_LOADING_INIT_HIDE" data-scroll="true" data-src="https://mimgnews.pstatic.net/image/upload/office_logo/006/2017/01/05/logo_006_18_20170105111205.png" height="18" style="display: none;" width="18"/>
# </div>
# <div class="subscribe_footer_text _OTHER_OFFICE_CHANNEL_SUBSCRIBE_WRAP">
# <div class="subscribe_footer_text_inner _OTHER_OFFICE_CHANNEL_SUBSCRIBE_BUTTON_WRAP">
# <small class="subscribe_footer_desc">언론사도 함께 구독해 보세요.</small>
# <div class="subscribe_guide_btn_wrapper">
# <button class="subscribe _CHANNEL_ADD _OTHER_OFFICE_CHANNEL_SUBSCRIBE_BUTTON" data-clk-add="arwj.press" data-oid="006" data-text="구독" type="button">
# 																			구독
# 																		</button>
# </div>
# </div>
# <div class="subscribe_footer_text_inner _OTHER_OFFICE_CHANNEL_SUBSCRIBE_FINISH_BUTTON_WRAP" style="display: none;">
# <a class="subscribe_footer_go" href="https://media.naver.com/press/006">
# 																		언론사를 함께 구독중입니다.
# 																	</a>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="rl_link_end">
# <div class="rl_content">
# <p class="rl_txt">전원책 "윤 대통령 독불장군식 밀어붙이기 국민들 절망"</p>
# <span class="rl_press">미디어오늘</span>
# <div class="rl_time">3시간전</div>
# </div>
# <div class="rl_img _LAZY_LOADING_WRAP _LAZY_LOADING_ERROR_HIDE">
# <div class="rl_border">
# <img alt="" class="_LAZY_LOADING" data-scroll="true" data-src="https://mimgnews.pstatic.net/image/origin/006/2024/09/02/125783.jpg?type=nf190_130&amp;ut=1725249431000" height="65" width="95"/>
# </div>
# </div>
# <a class="rl_coverlink" data-clk="arwj.art" href="https://media.naver.com/journalist/006/31569">
# <span class="blind">더보기</span>
# </a>
# </div>
# </li>
# <li class="rl_item _LAZY_LOADING_WRAP" data-loading-error-allowed="true">
# <div class="rl_subscribe_end _SUBSCRIBE_ELE _LAZY_LOADING_WRAP" data-subscribe-type="JOURNALIST">
# <a class="rl_subscribe_thumb _LAZY_LOADING_ERROR_HIDE" data-clk="arwj.art" href="https://media.naver.com/journalist/055/74704">
# <img alt="김기태 기자" class="_LAZY_LOADING _LAZY_LOADING_INIT_HIDE" data-scroll="true" data-src="https://mimgnews.pstatic.net/image/upload/journalist/2020/09/24/kkt.png?type=nf112_112" height="18" style="display: none;" width="18"/>
# </a>
# <div class="rl_subscribe_name">
# <a data-clk="arwj.art" href="https://media.naver.com/journalist/055/74704">김기태 기자</a>
# </div>
# <div class="subscribe_wrap">
# <button class="subscribe _SUBSCRIBE" data-channelkey="JOURNALIST_74704" data-clk="arwj.subp" data-close-layer-delay-ms="3000" data-open-layer-target-id="_SUBSCRIBE_GUIDE_pa9n7" type="button"><span class="subscribe_ico"><span>구독</span></span></button>
# <button class="subscribe on _UNSUBSCRIBE" data-channelkey="JOURNALIST_74704" data-clk="arwj.subc" data-messagevalue="김기태" data-type="journalist" style="display: none;" type="button"><span class="subscribe_ico"><span>구독중</span></span></button>
# <div class="subscribe_guide _OTHER_OFFICE_SUBSCRIBE_GUIDE_LAYER" id="_SUBSCRIBE_GUIDE_pa9n7" style="display: none;">
# <p class="subscribe_guide_em">구독해주셔서 감사합니다</p>
# <a class="_MOVE_TO_NEWS" href="#">
# <p class="subscribe_guide_p">김기태 기자의 기사는<br/>언론사별에서 볼 수 있습니다</p>
# </a>
# <a class="subscribe_guide_close _CLOSE" data-target="._OTHER_OFFICE_SUBSCRIBE_GUIDE_LAYER" href="#">닫기</a>
# <div class="subscribe_guide_footer _LAZY_LOADING_WRAP">
# <div class="subscribe_footer_thumb _LAZY_LOADING_ERROR_HIDE">
# <img alt="SBS" class="subscribe_footer_logo _LAZY_LOADING _LAZY_LOADING_INIT_HIDE" data-scroll="true" data-src="https://mimgnews.pstatic.net/image/upload/office_logo/055/2021/07/02/logo_055_18_20210702165821.jpg" height="18" style="display: none;" width="18"/>
# </div>
# <div class="subscribe_footer_text _OTHER_OFFICE_CHANNEL_SUBSCRIBE_WRAP">
# <div class="subscribe_footer_text_inner _OTHER_OFFICE_CHANNEL_SUBSCRIBE_BUTTON_WRAP">
# <small class="subscribe_footer_desc">언론사도 함께 구독해 보세요.</small>
# <div class="subscribe_guide_btn_wrapper">
# <button class="subscribe _CHANNEL_ADD _OTHER_OFFICE_CHANNEL_SUBSCRIBE_BUTTON" data-clk-add="arwj.press" data-oid="055" data-text="구독" type="button">
# 																			구독
# 																		</button>
# </div>
# </div>
# <div class="subscribe_footer_text_inner _OTHER_OFFICE_CHANNEL_SUBSCRIBE_FINISH_BUTTON_WRAP" style="display: none;">
# <a class="subscribe_footer_go" href="https://media.naver.com/press/055">
# 																		언론사를 함께 구독중입니다.
# 																	</a>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="rl_link_end">
# <div class="rl_content">
# <p class="rl_txt">방심위, 텔레그램 공동 대응 글로벌 협의체 구축 추진</p>
# <span class="rl_press">SBS</span>
# <div class="rl_time">2일전</div>
# </div>
# <div class="rl_img _LAZY_LOADING_WRAP _LAZY_LOADING_ERROR_HIDE">
# <div class="rl_border">
# <img alt="" class="_LAZY_LOADING" data-scroll="true" data-src="https://mimgnews.pstatic.net/image/origin/055/2024/08/30/1186120.jpg?type=nf190_130&amp;ut=1725011663000" height="65" width="95"/>
# </div>
# </div>
# <a class="rl_coverlink" data-clk="arwj.art" href="https://media.naver.com/journalist/055/74704">
# <span class="blind">더보기</span>
# </a>
# </div>
# </li>
# </ul>
# <ul class="ranking_list _FLICKING_CONTENT" data-index="1" style="margin-top: 0;">
# <li class="rl_item _LAZY_LOADING_WRAP" data-loading-error-allowed="true">
# <div class="rl_subscribe_end _SUBSCRIBE_ELE _LAZY_LOADING_WRAP" data-subscribe-type="JOURNALIST">
# <a class="rl_subscribe_thumb _LAZY_LOADING_ERROR_HIDE" data-clk="arwj.art" href="https://media.naver.com/journalist/056/78974">
# <img alt="진선민 기자" class="_LAZY_LOADING_REFRESH _LAZY_LOADING_INIT_HIDE" data-scroll="false" data-src="https://imgnews.pstatic.net/image/upload/spubs/oEG0000056/profile/2023/02/02/profile_185642546.jpg?type=nf112_112" height="18" style="display: none;" width="18"/>
# </a>
# <div class="rl_subscribe_name">
# <a data-clk="arwj.art" href="https://media.naver.com/journalist/056/78974">진선민 기자</a>
# </div>
# <div class="subscribe_wrap">
# <button class="subscribe _SUBSCRIBE" data-channelkey="JOURNALIST_78974" data-clk="arwj.subp" data-close-layer-delay-ms="3000" data-open-layer-target-id="_SUBSCRIBE_GUIDE_74wlb" type="button"><span class="subscribe_ico"><span>구독</span></span></button>
# <button class="subscribe on _UNSUBSCRIBE" data-channelkey="JOURNALIST_78974" data-clk="arwj.subc" data-messagevalue="진선민" data-type="journalist" style="display: none;" type="button"><span class="subscribe_ico"><span>구독중</span></span></button>
# <div class="subscribe_guide _OTHER_OFFICE_SUBSCRIBE_GUIDE_LAYER" id="_SUBSCRIBE_GUIDE_74wlb" style="display: none;">
# <p class="subscribe_guide_em">구독해주셔서 감사합니다</p>
# <a class="_MOVE_TO_NEWS" href="#">
# <p class="subscribe_guide_p">진선민 기자의 기사는<br/>언론사별에서 볼 수 있습니다</p>
# </a>
# <a class="subscribe_guide_close _CLOSE" data-target="._OTHER_OFFICE_SUBSCRIBE_GUIDE_LAYER" href="#">닫기</a>
# <div class="subscribe_guide_footer _LAZY_LOADING_WRAP">
# <div class="subscribe_footer_thumb _LAZY_LOADING_ERROR_HIDE">
# <img alt="KBS" class="subscribe_footer_logo _LAZY_LOADING_REFRESH _LAZY_LOADING_INIT_HIDE" data-scroll="false" data-src="https://mimgnews.pstatic.net/image/upload/office_logo/056/2021/10/28/logo_056_18_20211028103107.png" height="18" style="display: none;" width="18"/>
# </div>
# <div class="subscribe_footer_text _OTHER_OFFICE_CHANNEL_SUBSCRIBE_WRAP">
# ...
# <div class="ofhe_thumb _LAZY_LOADING_ERROR_HIDE">
# <div class="ofhe_image">
# <img alt="" class="_LAZY_LOADING" data-scroll="true" data-src="https://imgnews.pstatic.net/image/origin/008/2024/09/02/5084482.jpg?type=nf336_206"/>
# </div>
# </div>
# <div class="ofhe_headline">그 에어프라이어 세일 없는 이유 있었네…"싸게 팔지마" 가격 강제</div>
# <div class="ofhe_lede _LAZY_LOADING_ERROR_SHOW" style="display:none;">풀무원건강생활이 자신이 제작한 에어프라이어 등 주방가전 제품을 거래처에 공급하면서 판매가격을 일정 선 밑으로 낮추지 못하도록 강제했다가 적발됐다. 공정거래위원회는 2일 풀무원건강생활의 이러한 재판매가격유지행위에 대해</div>
# </a>
# </li>
# <li class="ofhe_item _LAZY_LOADING_WRAP" data-loading-error-allowed="true">
# <a class="ofhe_link _NLOG_IMPRESSION" data-clk="arw.art" data-extra='{"airs":{"session_id":"fu54abzvNlp4DDTt"}}' data-imp-gdid="8800010E_000000000000000002357326" data-imp-index="15" data-imp-url="https://n.news.naver.com/article/016/0002357326" href="/mnews/article/016/0002357326">
# <div class="ofhe_thumb _LAZY_LOADING_ERROR_HIDE">
# <div class="ofhe_image">
# <img alt="" class="_LAZY_LOADING" data-scroll="true" data-src="https://imgnews.pstatic.net/image/origin/016/2024/09/02/2357326.jpg?type=nf336_206"/>
# </div>
# </div>
# <div class="ofhe_headline">“장원영 질투로 연습생 데뷔 무산”…비방 영상으로 억대 수익 올려놓고 “명예훼손 아니다”는 유튜버</div>
# <div class="ofhe_lede _LAZY_LOADING_ERROR_SHOW" style="display:none;">걸그룹 '아이브'의 장원영(20) 등을 악의적으로 비방한 가짜 영상을 인터넷에 올려 억대 수익을 올린 30대 유튜버가 법정에서 혐의를 부인했다. 이 유튜버는 "장원영이 질투해 동료 연습생의 데뷔가 무산됐다", "또 </div>
# </a>
# </li>
# <li class="ofhe_item _LAZY_LOADING_WRAP" data-loading-error-allowed="true">
# <a class="ofhe_link _NLOG_IMPRESSION" data-clk="arw.art" data-extra='{"airs":{"session_id":"fu54abzvNlp4DDTt"}}' data-imp-gdid="880000ED_000000000000000003856134" data-imp-index="16" data-imp-url="https://n.news.naver.com/article/023/0003856134" href="/mnews/article/023/0003856134">
# <div class="ofhe_thumb _LAZY_LOADING_ERROR_HIDE">
# <div class="ofhe_image">
# <img alt="" class="_LAZY_LOADING" data-scroll="true" data-src="https://imgnews.pstatic.net/image/origin/023/2024/09/02/3856134.jpg?type=nf336_206"/>
# </div>
# </div>
# <div class="ofhe_headline">[단독] “너 방송 아니었으면 나락갔다” 20만 유튜버, 반려견 살해 혐의 피소</div>
# <div class="ofhe_lede _LAZY_LOADING_ERROR_SHOW" style="display:none;">지난 6월에는 미성년자 의제강간 혐의로 불구속 기소 자신이 키우던 반려견을 발로 차 살해하고 동물을 학대한 유튜버에 대해 경찰이 수사에 착수했다. 인천 서부경찰서는 지난달 29일 유명 유튜버 A(35·남)씨에 대해 </div>
# </a>
# </li>
# <li class="ofhe_item _LAZY_LOADING_WRAP" data-loading-error-allowed="true">
# <a class="ofhe_link _NLOG_IMPRESSION" data-clk="arw.art" data-extra='{"airs":{"session_id":"fu54abzvNlp4DDTt"}}' data-imp-gdid="880000C4_000000000000000002657685" data-imp-index="17" data-imp-url="https://n.news.naver.com/article/021/0002657685" href="/mnews/article/021/0002657685">
# <div class="ofhe_thumb _LAZY_LOADING_ERROR_HIDE">
# <div class="ofhe_image">
# <img alt="" class="_LAZY_LOADING" data-scroll="true" data-src="https://imgnews.pstatic.net/image/origin/021/2024/09/02/2657685.jpg?type=nf336_206"/>
# </div>
# </div>
# <div class="ofhe_headline">“연봉 ‘4억 콜’ 받더니… 응급의들 바로 병원 옮겨”</div>
# <div class="ofhe_lede _LAZY_LOADING_ERROR_SHOW" style="display:none;">세종충남대 응급실 최근 4명 사직 몸값 오르자 이직… 야간진료 중단 비싼 의사 인건비·배후진료 차질 응급실 구조적 병폐가 파행 원인 최근 응급실 파행 논란이 불거진 가운데 의료계 안팎에서는 비싼 의사 인건비와 배후 </div>
# </a>
# </li>
# <li class="ofhe_item _LAZY_LOADING_WRAP" data-loading-error-allowed="true">
# <a class="ofhe_link _NLOG_IMPRESSION" data-clk="arw.art" data-extra='{"airs":{"session_id":"fu54abzvNlp4DDTt"}}' data-imp-gdid="880000F2_000000000000000003383695" data-imp-index="18" data-imp-url="https://n.news.naver.com/article/025/0003383695" href="/mnews/article/025/0003383695">
# <div class="ofhe_thumb _LAZY_LOADING_ERROR_HIDE">
# <div class="ofhe_image">
# <img alt="" class="_LAZY_LOADING" data-scroll="true" data-src="https://imgnews.pstatic.net/image/origin/025/2024/09/02/3383695.jpg?type=nf336_206"/>
# </div>
# </div>
# <div class="ofhe_headline">달리는 차 뒷문 열리며 사람 쿵…일주일만에 또 생명 살린 해경</div>
# <div class="ofhe_lede _LAZY_LOADING_ERROR_SHOW" style="display:none;">일주일 전 친구와 떠난 휴가지에서 심정지 환자를 발견하고 신속 구조조치로 생명을 살린 30대 해양경찰관이 이번에는 도로에 쓰러진 10대 심정지 환자를 구했다. 2일 경남 통영해양경찰서에 따르면 통영해경 소속 반윤혁(</div>
# </a>
# </li>
# </ul>
# </div>
# <div class="flick-panel">
# <ul class="ofhe_list">
# <li class="ofhe_item _LAZY_LOADING_WRAP" data-loading-error-allowed="true">
# <a class="ofhe_link _NLOG_IMPRESSION" data-clk="arw.art" data-extra='{"airs":{"session_id":"fu54abzvNlp4DDTt"}}' data-imp-gdid="88000108_000000000000000004387171" data-imp-index="19" data-imp-url="https://n.news.naver.com/article/011/0004387171" href="/mnews/article/011/0004387171">
# <div class="ofhe_thumb _LAZY_LOADING_ERROR_HIDE">
# <div class="ofhe_image">
# <img alt="" class="_LAZY_LOADING" data-scroll="true" data-src="https://imgnews.pstatic.net/image/origin/011/2024/09/02/4387171.jpg?type=nf336_206"/>
# </div>
# </div>
# <div class="ofhe_headline">"각방 쓰고 애는 안 낳아요" 이런 MZ부부 많더니 결국…아파트 구조까지 바꿨다는데 무슨 일?</div>
# <div class="ofhe_lede _LAZY_LOADING_ERROR_SHOW" style="display:none;">고령화, 1~2인 가구 증가 등 인구구조가 급변하면서 아파트 평면 설계에도 변화가 일기 시작했다. 4인 가족 등 중심의 설계에서 달라진 부부, 가족 관계 등을 반영해 자녀 드레스룸, ‘각방 부부’을 위한 침실 설계 </div>
# </a>
# </li>
# <li class="ofhe_item _LAZY_LOADING_WRAP" data-loading-error-allowed="true">
# <a class="ofhe_link _NLOG_IMPRESSION" data-clk="arw.art" data-extra='{"airs":{"session_id":"fu54abzvNlp4DDTt"}}' data-imp-gdid="88000127_000000000000000012760721" data-imp-index="20" data-imp-url="https://n.news.naver.com/article/003/0012760721" href="/mnews/article/003/0012760721">
# <div class="ofhe_thumb _LAZY_LOADING_ERROR_HIDE">
# <div class="ofhe_image">
# <img alt="" class="_LAZY_LOADING" data-scroll="true" data-src="https://imgnews.pstatic.net/image/origin/003/2024/09/02/12760721.jpg?type=nf336_206"/>
# </div>
# </div>
# <div class="ofhe_headline">"커서 뭐가 되고 싶니"…10년 동안 딸 첫 등교 영상 찍은 아버지</div>
# <div class="ofhe_lede _LAZY_LOADING_ERROR_SHOW" style="display:none;">미국의 한 아버지가 10년이 넘는 기간 동안 딸의 매년 첫 등교 날에 찍은 인터뷰를 공개해 감동을 주고있다. 1일(현지시각) 데일리메일에 따르면 47세 기상학자인 레이 페텔린은 자신의 엑스(X·구 트위터)에 영상을 </div>
# </a>
# </li>
# <li class="ofhe_item _LAZY_LOADING_WRAP" data-loading-error-allowed="true">
# <a class="ofhe_link _NLOG_IMPRESSION" data-clk="arw.art" data-extra='{"airs":{"session_id":"fu54abzvNlp4DDTt"}}' data-imp-gdid="88000107_000000000000000005028482" data-imp-index="21" data-imp-url="https://n.news.naver.com/article/015/0005028482" href="/mnews/article/015/0005028482">
# <div class="ofhe_thumb _LAZY_LOADING_ERROR_HIDE">
# <div class="ofhe_image">
# <img alt="" class="_LAZY_LOADING" data-scroll="true" data-src="https://imgnews.pstatic.net/image/origin/015/2024/09/02/5028482.jpg?type=nf336_206"/>
# </div>
# </div>
# <div class="ofhe_headline">장원영 괴롭힌 유튜버, 수억원 벌어놓고…"고의 아니었다"</div>
# <div class="ofhe_lede _LAZY_LOADING_ERROR_SHOW" style="display:none;">그룹 아이브 멤버 장원영 등 유명 아이돌에 대해 사실 확인이 되지 않은 악의적인 비방 내용을 콘텐츠로 만들어 억대 수익을 올린 30대 유튜버가 혐의를 부인했다. 2일 인천지법 형사11단독(김샛별 판사) 심리로 A씨(</div>
# </a>
# </li>
# <li class="ofhe_item _LAZY_LOADING_WRAP" data-loading-error-allowed="true">
# <a class="ofhe_link _NLOG_IMPRESSION" data-clk="arw.art" data-extra='{"airs":{"session_id":"fu54abzvNlp4DDTt"}}' data-imp-gdid="88000149_000000000000000001177870" data-imp-index="22" data-imp-url="https://n.news.naver.com/article/215/0001177870" href="/mnews/article/215/0001177870">
# <div class="ofhe_thumb _LAZY_LOADING_ERROR_HIDE">
# <div class="ofhe_image">
# <img alt="" class="_LAZY_LOADING" data-scroll="true" data-src="https://imgnews.pstatic.net/image/origin/215/2024/09/02/1177870.jpg?type=nf336_206"/>
# </div>
# </div>
# <div class="ofhe_headline">백종원이 살린 예산시장…사흘 행사에 35만명 '우르르'</div>
# <div class="ofhe_lede _LAZY_LOADING_ERROR_SHOW" style="display:none;">충남 예산군과 더본코리아가 올해로 2회째 예산상설시장 일원에서 개최한 '2024 예산 맥주 페스티벌' 성황리에 마무리됐다. 예산군은 지난달 30일부터 사흘 동안 예산상설시장 일원에서 열린 '예산 맥주 페스티벌'에 3</div>
# </a>
# </li>
# <li class="ofhe_item _LAZY_LOADING_WRAP" data-loading-error-allowed="true">
# <a class="ofhe_link _NLOG_IMPRESSION" data-clk="arw.art" data-extra='{"airs":{"session_id":"fu54abzvNlp4DDTt"}}' data-imp-gdid="880000AD_000000000000000002899533" data-imp-index="23" data-imp-url="https://n.news.naver.com/article/029/0002899533" href="/mnews/article/029/0002899533">
# <div class="ofhe_thumb _LAZY_LOADING_ERROR_HIDE">
# <div class="ofhe_image">
# <img alt="" class="_LAZY_LOADING" data-scroll="true" data-src="https://imgnews.pstatic.net/image/origin/029/2024/09/02/2899533.jpg?type=nf336_206"/>
# </div>
# </div>
# <div class="ofhe_headline">[속보] `단식 중단` 의협회장 "허겁지겁 의대 증원할 이유 없어…국민이 나서야"</div>
# <div class="ofhe_lede _LAZY_LOADING_ERROR_SHOW" style="display:none;">국민들께서 이 사태 멈춰줘야" "단식 마치고 의사 힘 모으겠다" 임현택 대한의사협회(의협) 회장은 2일 정부의 의대 증원 정책과 관련, "무리한 정책을 일단 멈추고, 의료계와 논의하라고 국민들께서 정부에 요구해줄 </div>
# </a>
# </li>
# <li class="ofhe_item _LAZY_LOADING_WRAP" data-loading-error-allowed="true">
# <a class="ofhe_link _NLOG_IMPRESSION" data-clk="arw.art" data-extra='{"airs":{"session_id":"fu54abzvNlp4DDTt"}}' data-imp-gdid="880000FF_000000000000000005235448" data-imp-index="24" data-imp-url="https://n.news.naver.com/article/014/0005235448" href="/mnews/article/014/0005235448">
# <div class="ofhe_thumb _LAZY_LOADING_ERROR_HIDE">
# <div class="ofhe_image">
# <img alt="" class="_LAZY_LOADING" data-scroll="true" data-src="https://imgnews.pstatic.net/image/origin/014/2024/09/02/5235448.jpg?type=nf336_206"/>
# </div>
# </div>
# <div class="ofhe_headline">"삐끼삐끼~" 이주은 치어리더 '스타' 만든 아웃송 원곡·탄생 과정은</div>
# <div class="ofhe_lede _LAZY_LOADING_ERROR_SHOW" style="display:none;">미국 일간 뉴욕타임스(NYT)가 최근 틱톡(TikTok) 등 온라인에서 중독성 있는 춤으로 화제가 된 한국 야구 치어리더들의 인기를 조명하고 나선 가운데 기아 타이거즈 대표 아웃송 원곡과 탄생 과정 등에 관심이 쏠리</div>
# </a>
# </li>
# </ul>
# </div>
# <div class="flick-panel">
# <ul class="ofhe_list">
# <li class="ofhe_item _LAZY_LOADING_WRAP" data-loading-error-allowed="true">
# <a class="ofhe_link _NLOG_IMPRESSION" data-clk="arw.art" data-extra='{"airs":{"session_id":"fu54abzvNlp4DDTt"}}' data-imp-gdid="8800006F_000000000000000001722086" data-imp-index="25" data-imp-url="https://n.news.naver.com/article/005/0001722086" href="/mnews/article/005/0001722086">
# <div class="ofhe_thumb _LAZY_LOADING_ERROR_HIDE">
# <div class="ofhe_image">
# <img alt="" class="_LAZY_LOADING" data-scroll="true" data-src="https://imgnews.pstatic.net/image/origin/005/2024/09/02/1722086.jpg?type=nf336_206"/>
# </div>
# </div>
# <div class="ofhe_headline">3500년 전 항아리 깬 소년… 박물관이 한 ‘뜻밖의 대응’</div>
# <div class="ofhe_lede _LAZY_LOADING_ERROR_SHOW" style="display:none;">이스라엘 하이파대 헤흐트박물관에 전시된 3500년 전 항아리를 실수로 깬 4세 소년이 재방문했다고 AP통신이 31일(현지시간) 보도했다. 항아리를 깬 소년은 아리엘 헬러. 보도에 따르면 헬러는 지난 30일 가족과 함</div>
# </a>
# </li>
# <li class="ofhe_item _LAZY_LOADING_WRAP" data-loading-error-allowed="true">
# <a class="ofhe_link _NLOG_IMPRESSION" data-clk="arw.art" data-extra='{"airs":{"session_id":"fu54abzvNlp4DDTt"}}' data-imp-gdid="880000D8_000000000000000014906656" data-imp-index="26" data-imp-url="https://n.news.naver.com/article/001/0014906656" href="/mnews/article/001/0014906656">
# <div class="ofhe_thumb _LAZY_LOADING_ERROR_HIDE">
# <div class="ofhe_image">
# <img alt="" class="_LAZY_LOADING" data-scroll="true" data-src="https://imgnews.pstatic.net/image/origin/001/2024/09/02/14906656.jpg?type=nf336_206"/>
# </div>
# </div>
# <div class="ofhe_headline">장원영 비방해 억대 수익 올린 유튜버 "명예훼손 아니다"</div>
# <div class="ofhe_lede _LAZY_LOADING_ERROR_SHOW" style="display:none;">첫 재판서 혐의 부인…안경·마스크로 얼굴 가린 채 출석 걸그룹 '아이브'의 장원영(20) 등을 악의적으로 비방한 가짜 영상을 인터넷에 올리고 억대 수익을 챙긴 30대 유튜버가 법정에서 혐의를 부인했다. 정보통신망 이</div>
# </a>
# </li>
# <li class="ofhe_item _LAZY_LOADING_WRAP" data-loading-error-allowed="true">
# <a class="ofhe_link _NLOG_IMPRESSION" data-clk="arw.art" data-extra='{"airs":{"session_id":"fu54abzvNlp4DDTt"}}' data-imp-gdid="88156f6f_000000000000000000079637" data-imp-index="27" data-imp-url="https://n.news.naver.com/article/346/0000079637" href="/mnews/article/346/0000079637">
# <div class="ofhe_thumb _LAZY_LOADING_ERROR_HIDE">
# <div class="ofhe_image">
# <img alt="" class="_LAZY_LOADING" data-scroll="true" data-src="https://imgnews.pstatic.net/image/origin/346/2024/09/02/79637.jpg?type=nf336_206"/>
# </div>
# </div>
# <div class="ofhe_headline">맛있으면서 살까지 빼주는 ‘추천 간식’ 7가지</div>
# <div class="ofhe_lede _LAZY_LOADING_ERROR_SHOW" style="display:none;">최근 건강관리 흐름은 ‘헬시 플레저’로 귀결된다. 즐겁게 건강을 챙기자는 움직임을 말하며 식품업계에서도 맛있고 지속가능한 저칼로리·저당 제품을 잇달아 출시하고 있다. 고단백 저탄수화물 식품은 포만감을 오래 유지하고 </div>
# </a>
# </li>
# <li class="ofhe_item _LAZY_LOADING_WRAP" data-loading-error-allowed="true">
# <a class="ofhe_link _NLOG_IMPRESSION" data-clk="arw.art" data-extra='{"airs":{"session_id":"fu54abzvNlp4DDTt"}}' data-imp-gdid="880000ED_000000000000000003856119" data-imp-index="28" data-imp-url="https://n.news.naver.com/article/023/0003856119" href="/mnews/article/023/0003856119">
# <div class="ofhe_thumb _LAZY_LOADING_ERROR_HIDE">
# <div class="ofhe_image">
# <img alt="" class="_LAZY_LOADING" data-scroll="true" data-src="https://imgnews.pstatic.net/image/origin/023/2024/09/02/3856119.jpg?type=nf336_206"/>
# </div>
# </div>
# <div class="ofhe_headline">얼음주머니 얹고 ‘잇몸 만개’… 반응 터진 신유빈 바나나맛 우유 광고</div>
# <div class="ofhe_lede _LAZY_LOADING_ERROR_SHOW" style="display:none;">탁구 국가대표 선수 신유빈이 촬영한 빙그레의 바나나맛 우유 광고가 화제를 모으고 있다. 빙그레는 2일 바나나맛 우유 모델 신유빈과 함께한 신규 광고를 공개했다고 밝혔다. 빙그레에 따르면, 이번 광고는 2004년생인 </div>
# </a>
# </li>
# <li class="ofhe_item _LAZY_LOADING_WRAP" data-loading-error-allowed="true">
# <a class="ofhe_link _NLOG_IMPRESSION" data-clk="arw.art" data-extra='{"airs":{"session_id":"fu54abzvNlp4DDTt"}}' data-imp-gdid="88000149_000000000000000001177790" data-imp-index="29" data-imp-url="https://n.news.naver.com/article/215/0001177790" href="/mnews/article/215/0001177790">
# <div class="ofhe_thumb _LAZY_LOADING_ERROR_HIDE">
# <div class="ofhe_image">
# <img alt="" class="_LAZY_LOADING" data-scroll="true" data-src="https://imgnews.pstatic.net/image/origin/215/2024/09/02/1177790.jpg?type=nf336_206"/>
# </div>
# </div>
# <div class="ofhe_headline">"이자내고 밥만 먹었는데"…여윳돈 고작 100만원</div>
# <div class="ofhe_lede _LAZY_LOADING_ERROR_SHOW" style="display:none;">통계청 국가통계포털에 따르면 올해 2분기 가구 흑자액(전국·1인이상·실질)은 월평균 100만9천원으로 1년 전보다 1만8천원(1.7%) 감소했다. 흑자액은 소득에서 이자비용·세금 등 비소비지출과 의식주 비용 등 소비</div>
# </a>
# </li>
# <li class="ofhe_item _LAZY_LOADING_WRAP" data-loading-error-allowed="true">
# <a class="ofhe_link _NLOG_IMPRESSION" data-clk="arw.art" data-extra='{"airs":{"session_id":"fu54abzvNlp4DDTt"}}' data-imp-gdid="88000385_000000000000000005466652" data-imp-index="30" data-imp-url="https://n.news.naver.com/article/277/0005466652" href="/mnews/article/277/0005466652">
# <div class="ofhe_thumb _LAZY_LOADING_ERROR_HIDE">
# <div class="ofhe_image">
# <img alt="" class="_LAZY_LOADING" data-scroll="true" data-src="https://imgnews.pstatic.net/image/origin/277/2024/09/02/5466652.jpg?type=nf336_206"/>
# </div>
# </div>
# <div class="ofhe_headline">남편 불륜에 맞바람 피운 아내, 불륜남에 "남편 폭행해달라"</div>
# <div class="ofhe_lede _LAZY_LOADING_ERROR_SHOW" style="display:none;">남편의 불륜에 앙심을 품은 아내가 맞바람을 피우고 자신의 불륜 상대에게 남편 폭행까지 사주한 사실이 드러났다. 지난달 31일 TBC '사건반장'에 따르면 10년 전 40대 남성 A씨는 5세 연상의 재력가 여성 B씨와</div>
# </a>
# </li>
# </ul>
# </div>
# </div>
# </div>
# <div class="ofhe_paginate pg">
# <div class="pg_num_area pg_num_area_v2">
# <button class="pg_btn_prev _FLICKING_PREV" type="button"><span class="blind">이전 뉴스들 보기</span></button>
# <div class="_FLICKING_INDICATOR" data-count="5"></div>
# <div class="pg_line"></div>
# <div class="pg_num pg_num">5</div>
# <button class="pg_btn_next _FLICKING_NEXT" type="button"><span class="blind">다음 뉴스들 보기</span></button>
# </div>
# </div>
# <script class="_FLICKING_INDICATOR_TEMPLATE _PC" type="x-tmpl-mustache">
# 	{{#selected}}
# 		<div class="pg_num pg_num_cur">{{number}}</div>
# 	{{/selected}}
# 	</script>
# </div>
# </div>
# <div class="outside_area _OUTSIDE_AREA">
# <div class="outside_area_inner _GRID_TEMPLATE_COLUMN_ASIDE _OUTSIDE_AREA_INNER"></div>
# </div>
# <aside class="main_aside _MAIN_ASIDE">
# <div class="main_aside_inner _MAIN_ASIDE_INNER">
# <h3 class="blind">구독</h3>
# <script class="_LAZY_LOADING_IFRAME" type="x-tmpl-mustache">
# 			<iframe class="_aside _GRID_TEMPLATE_ASIDE_IFRAME" src="https://news.naver.com/aside?oid=011" data-allow-domain="https://news.naver.com" style="visibility: hidden;" frameborder="no" scrolling="no" width="100%" title="구독"></iframe>
# 			</script>
# </div>
# </aside>
# </div>

# %%
for box in boxes:
    articles = box.select('div.sa_text')
    # print(len(articles))
    for article in articles:
        # 제목, url, 언론사 # 댓글수
        title = article.select_one('strong.sa_text_strong').text
        news_url = article.select_one('a')['href']
        news_id = news_url.split('/')[-1]
        press = article.select_one('div.sa_text_press').text
        print(title[:10], press, news_id)
# Out:
# 6월 은행 예금·대 연합뉴스TV 0000673983
# [이코노미 플러스] 강원일보 0001059409
# 삼성증권 새 IB1 뉴시스 0012701537
# 부산은행 끌고, 경 국제신문 0000080042
# 일본은행, 4개월만 디지털타임스 0002891958
# KB손보, 115명 세계일보 0003955998
# 하나銀 반년 만에  디지털타임스 0002891952
# [마켓인]“1조 규 이데일리 0005801740
# 키움증권 2분기 영 한겨레 0002700653
# 푸본현대생명, 소외 이데일리 0005801739
# 3년 만에 희망퇴직 파이낸셜뉴스 0005221644
# 손해보험협회, 우수 매일경제 0005343494
# KB손보, 36개월 디지털타임스 0002891940
# 김병환 금융위원장  이데일리 0005801715
# 일본은행 단기 정책 매일신문 0000895228
# 삼성전자 추격하는  매일신문 0000895226
# `환승 대출` 23 디지털타임스 0002891933
# 우수설계사 인증 ‘ 국민일보 0001714805
# [오일 Drive] 이데일리 0005801704
# BNK금융그룹, 예 부산일보 0001282011
# 美 금리인하 예상  파이낸셜뉴스 0005221602
# BNK·JB 웃고  매일경제 0005343476
# [표] 외국환율고시 매일경제 0005343475
# 티메프 환불 떠안은 매일경제 0005343474
# 취임식 생략한 금융 매일경제 0005343473
# [표] 당좌거래정지 매일경제 0005343472
# 부동산PF 연체액  매일경제 0005343470
# 주담대 금리 8개월 국민일보 0001714802
# "경제 불확실성 도 파이낸셜뉴스 0005221572
# 손보협, ‘불완전판 파이낸셜뉴스 0005221571
# "티메프 사태 신속 파이낸셜뉴스 0005221570
# 국민銀 노사 ‘1천 파이낸셜뉴스 0005221569
# 강신숙 행장 "내부 파이낸셜뉴스 0005221568
# 네이버페이, 빠른정 파이낸셜뉴스 0005221566
# 취임하자마자 업무  파이낸셜뉴스 0005221565
# 호재 소진된 비트코 조선비즈 0001009056

# %%
import datetime
import calendar

p_next = soup.select_one('div.section_latest_article')['data-cursor']

t = datetime.datetime.now()
p_time = calendar.timegm(t.timetuple())

p_next, p_time
# Out:
# ('2024073116521181976', 1725138398)

# %% [markdown]
# 1725105317255

# %% [markdown]
# 다음 페이지

# %%
next_url = f"https://news.naver.com/section/template/SECTION_ARTICLE_LIST_FOR_LATEST?sid=101&sid2=259&cluid=&pageNo=1&date=20240731&next={p_next}&_={p_time}"
next_url
# Out:
# 'https://news.naver.com/section/template/SECTION_ARTICLE_LIST_FOR_LATEST?sid=101&sid2=259&cluid=&pageNo=1&date=20240731&next=2024073118000909056&_=1725137962'

# %%
res = requests.get(next_url, headers= headers)
res
# Out:
# <Response [200]>

# %%
import json

# %%
content_json = json.loads(res.text)
content_json
# Out:
# {'component': {},
#  'renderedComponent': {'SECTION_ARTICLE_LIST_FOR_LATEST': '<div class="section_title _CALENDAR_WRAP">\n\t<div class="section_title_inner">\n\t\t<h3 class="section_title_h">금융</h3>\n\t\t<div class="section_title_sort">\n\t\t\t<button type="button" class="section_title_btn _LINK _CALENDAR_TODAY_LINK" data-url="/breakingnews/section/101/259" data-clk="alistlatest">최신순</button>\n\t\t\t<button type="button" class="section_title_btn is_selected is_closed is_colored _CALENDAR_LAYER_TOGGLE" data-clk="caltoggle">2024.07.31.</button>\n\t\t</div>\n\t</div>\n\t<div class="calendar">\n\t\t<div class="calendar_layer is_hidden _CALENDAR" data-start-date="20140831" data-selected-date="20240731"></div>\n\t\t<script type="x-tmpl-mustache" class="_CALENDAR_TEMPLATE">\n\t\t<div class="calendar_layer_head">\n\t\t\t<button type="button" class="calendar_layer_prev clndr-previous-button">\n\t\t\t\t<span class="blind">이전</span>\n\t\t\t</button>\n\t\t\t<div class="calendar_layer_date">\n\t\t\t\t<strong class="calendar_layer_date_text">{{year}}.{{monthInNumber}}</strong>\n\t\t\t\t<button type="button" class="calendar_layer_today _CALENDAR_TODAY" data-clk="caltoday">오늘</button>\n\t\t\t</div>\n\t\t\t<button type="button" class="calendar_layer_next clndr-next-button">\n\t\t\t\t<span class="blind">다음</span>\n\t\t\t</button>\n\t\t</div>\n\t\t<div class="calendar_layer_body">\n\t\t\t<table>\n\t\t\t\t<caption><span class="blind">캘린더</span></caption>\n\t\t\t\t<thead>\n\t\t\t\t\t<tr>\n\t\t\t\t\t\t{{#daysOfTheWeek}}\n\t\t\t\t\t\t<th scope="col">{{.}}</th>\n\t\t\t\t\t\t{{/daysOfTheWeek}}\n\t\t\t\t\t</tr>\n\t\t\t\t</thead>\n\t\t\t\t<tbody>\n\t\t\t\t\t{{#chunkedDays}}\n\t\t\t\t\t<tr>\n\t\t\t\t\t\t{{#.}}\n\t\t\t\t\t\t<td class="{{classes}}">\n\t\t\t\t\t\t\t<a href="javascript:;" class="calendar_a" data-clk="caldate">{{day}}</a>\n\t\t\t\t\t\t</td>\n\t\t\t\t\t\t{{/.}}\n\t\t\t\t\t</tr>\n\t\t\t\t\t{{/chunkedDays}}\n\t\t\t\t</tbody>\n\t\t\t</table>\n\t\t\t<button type="button" class="calendar_layer_close _CALENDAR_LAYER_TOGGLE" data-clk="calclose">\n\t\t\t\t<span class="blind">닫기</span>\n\t\t\t</button>\n\t\t</div>\n\t\t</script>\n\t</div>\n</div>\n<div class="section_latest">\n<div class="section_component as_section_article_list _PERSIST_CONTENT" data-persist="SECTION_ARTICLE_LIST_FOR_LATEST">\n<div class="section_latest_article _CONTENT_LIST _PERSIST_META" data-sid="101" data-sid2="259" data-cluid="" data-has-next="true" data-cursor-name="next" data-cursor="2024073116521181976" data-page-no="2" data-date="20240731" data-template="SECTION_ARTICLE_LIST_FOR_LATEST" data-nclk="alist" data-persist="SECTION_ARTICLE_LIST_FOR_LATEST_META" data-persist-meta-restore="true">\n<div class="section_article _TEMPLATE" data-template-id="SECTION_ARTICLE_LIST_FOR_LATEST">\n\t<ul class="sa_list">\n\t\t<li class="sa_item _LAZY_LOADING_WRAP">\n\t\t\t<div class="sa_item_inner">\n\t\t\t\t<div class="sa_item_flex">\n\t\t\t\t\t<div class="sa_thumb _LAZY_LOADING_ERROR_HIDE">\n\t\t\t\t\t\t<div class="sa_thumb_inner">\n\t\t\t\t\t\t\t<a href="https://n.news.naver.com/mnews/article/468/0001081863" class="sa_thumb_link _NLOG_IMPRESSION" data-clk="alist" data-rank="37" data-gdid="88156f78_000000000000000001081863" data-imp-url="https://n.news.naver.com/mnews/article/468/0001081863">\n\t\t\t\t\t\t\t\t<img data-src="https://mimgnews.pstatic.net/image/origin/468/2024/07/31/1081863.jpg?type&#x3D;nf220_150" class="_LAZY_LOADING _LAZY_LOADING_INIT_HIDE" width="110" height="75" alt="KB국민은행, 금융 취약계층에 ‘따뜻한 금융’의 손길" onerror="this.outerHTML=\'<span class=&quot;noimage&quot;></span>\'" style="display: none;">\n\t\t\t\t\t\t\t</a>\n\t\t\t\t\t\t</div>\n\t\t\t\t\t</div>\n\t\t\t\t\t<div class="sa_text">\n\t\t\t\t\t\t<a href="https://n.news.naver.com/mnews/article/468/0001081863" class="sa_text_title _NLOG_IMPRESSION" data-clk="alist" data-rank="37" data-gdid="88156f78_000000000000000001081863" data-imp-url="https://n.news.naver.com/mnews/article/468/0001081863">\n\t\t\t\t\t\t\t<strong class="sa_text_strong">KB국민은행, 금 ...
#  'uhv': ''}

# %%
res_text = content_json['renderedComponent']['SECTION_ARTICLE_LIST_FOR_LATEST']

# %%
soup = BeautifulSoup(res_text, 'html.parser')

# %%
boxes = soup.select('ul.sa_list')
len(boxes)
# Out:
# 6

# %%
for box in boxes:
    articles = box.select('div.sa_text')
    # print(len(articles))
    for article in articles:
        # 제목, url, 언론사 # 댓글수
        title = article.select_one('strong.sa_text_strong').text
        news_url = article.select_one('a')['href']
        news_id = news_url.split('/')[-1]
        press = article.select_one('div.sa_text_press').text
        print(title[:], press, sep=' / ')
# Out:
# KB국민은행, 금융 취약계층에 ‘따뜻한 금융’의 손길 / 스포츠서울
# 김병환 신임 금융위원장 "티메프 사태 지원, 꼼꼼히 챙기겠다"[이슈+] / 이코노미스트
# "4대 리스크 해소"…김병환號 '티메프'가 첫 시험대 / 서울경제
# 금융당국 "e커머스 정산주기 단축…PG사 관리체계도 손질" / 한국경제
# 임태중 상상인증권 대표, 임기 8개월 남기고 사임 / 연합뉴스
# 5대銀 대출금리 뚝뚝…예대차 두달 연속 축소 / 서울경제
# 저축은행 토지담보대출 연체율 20%로 껑충 / 한국경제
# 김병환 "가계부채 철저 관리" / 한국경제
# 주담대 금리, 30개월 만에 최저 / 한국경제
# 하이투자증권, 비대면 신규 고객 거래 수수료 0.01% 이벤트 / 서울경제
# 하나은행, 상반기 상생금융지원 3207억원 투입 / 이데일리
# 주담대 갈아타기 수수료율, 네이버페이가 낮네 / 한국경제
# "5년간 불완전판매 제로"…손보 최고 설계사 2807명 / 한국경제
# 농협은행 강원본부, 소상공인을 위한 첫걸음 금융지원 협약식 / 연합뉴스
# 우리은행, 소장도서 2만5000권 밀알복지재단에 기부...도서판매 수익금도 쾌척 / 스포츠서울
# 신한카드 "서울시 골목상권 이용하면 7000원 돌려줘요" / 디지털타임스
# 삼성증권, 이충훈 부사장 신임 IB1부문장 임명 / 디지털타임스
# 라이나손보, 취약계층 아동 지원 / 한국경제
# 우리은행, 소장도서 2만5000권 기부 / 한국경제
# 하나금융 계열 하나대체투자 도덕적 해이에 철거업체는 부도 직전 몰려 / 매일신문
# "일본 금리 인상"…한국 금융시장 영향은 / 뉴시스
# 신한은행, 상반기 민생금융지원 2436억원 투입 / 이데일리
# 국민은행, 3721억원 규모 민생금융 지원 / 이데일리
# 비은행 계열사 따라 실적 '희비'..BNK·JB 웃고 DGB 울고 / 머니투데이
# 국고채 금리, '매파 금통위'에 일제히 상승…3년물 3.004%(종합) / 연합뉴스
# 韓·美·日 통화정책 온도 차 ‘변수’…난이도 높아진 증시 전망 / 데일리안
# NH농협은행 강원본부, 소상공인 위한 전용상품 출시 / 강원일보
# 경기도, 파주·김포 이어 고양에 '말라리아 경보' 발령 / 연합뉴스
# [현장]"중장년도 코인 투자한다"…빗썸라운지 강남, 3일 만에 600명 찾았다 / 데일리안
# 김병환, 티메프 셀러·소비자 구제…대주주·경영진엔 "책임 물을 것" / 디지털타임스
# "韓日 디지털자산 운용 협력"...제9회 한국-일본 핀테크 혁신 웨비나 개최 / 파이낸셜뉴스
# "대출금리 하락 효과" 시중銀, 서민금융 제외 예대금리차 줄었다 / 파이낸셜뉴스
# 올해 신용카드 우수모집인 700명...전년 比 4.9%p 뛰어 / 파이낸셜뉴스
# BNK금융, 상반기 순익 4923억…전년比 7%↑ / 데일리안
# KB금융공익재단, 성남시와 청년 대상 전세사기 예방교육 / 뉴스1
# [인사] SGI서울보증 / 부산일보

# %%
p_next = soup.select_one('div.section_latest_article')['data-cursor']

t = datetime.datetime.now()
p_time = calendar.timegm(t.timetuple())

p_next, p_time
# Out:
# ('2024073116521181976', 1725140147)

# %%
p_next = "2024073100003709141"

# %%
date_str = '20240731'

next_url = f"https://news.naver.com/section/template/SECTION_ARTICLE_LIST_FOR_LATEST?sid=101&sid2=259&cluid=&pageNo=1&date={date_str}&next={p_next}&_={p_time}"
next_url
# Out:
# 'https://news.naver.com/section/template/SECTION_ARTICLE_LIST_FOR_LATEST?sid=101&sid2=259&cluid=&pageNo=1&date=20240731&next=2024073100003709141&_=1725140147'

# %%
res = requests.get(next_url, headers= headers)
content_json = json.loads(res.text)
res_text = content_json['renderedComponent']['SECTION_ARTICLE_LIST_FOR_LATEST']
soup = BeautifulSoup(res_text, 'html.parser')

# %%
p_next = soup.select_one('div.section_latest_article')['data-cursor']
p_time = calendar.timegm(dt.datetime.now().timetuple())
p_next
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[73], line 1
# ----> 1 p_next = soup.select_one('div.section_latest_article')['data-cursor']
#       2 p_time = calendar.timegm(dt.datetime.now().timetuple())
#       3 p_next
#
# TypeError: 'NoneType' object is not subscriptable
