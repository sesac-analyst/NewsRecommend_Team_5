# %%
import requests
from bs4 import BeautifulSoup

import datetime as dt
from dateutil import rrule

import pandas as pd
import json

# %%
import pandas as pd
import os

# %%
import datetime as dt
from dateutil import rrule

# %%
import ast

# %%
f_path = os.path.join('D:\python_project\sesac02\data', 'news_naver_IT.csv')
df = pd.read_csv(f_path)
df

# %% [markdown]
# 일단 첫 화면 가져오는 것부터

# %%
sector_url = "https://news.naver.com/breakingnews/section/105/731?date=20230802"

# %%
headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/127.0.0.0 Safari/537.36'}

# %%
res = requests.get(sector_url, headers= headers)
soup = BeautifulSoup(res.text, 'html.parser')
res
# Out:
# <Response [200]>

# %%
res.text
# Out:
# '<!doctype html>\n<html lang="ko" data-useragent="Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/127.0.0.0 Safari/537.36">\n\t<head>\n\t\t<meta charset="utf-8">\n\t\t<meta http-equiv="X-UA-Compatible" content="IE=edge">\n\t\t<meta name="referrer" contents="always">\n\t\t<meta http-equiv="refresh" content="600">\n\t\t<meta name="viewport" content="width=device-width, initial-scale=1.0, maximum-scale=1.0, minimum-scale=1.0, user-scalable=no" />\n\t\t<meta property="og:title" content="정치 : 네이버 뉴스">\n\t\t<meta property="og:type" content="website">\n\t\t<meta property="og:url" content="https://news.naver.com/breakingnews/section/100/264?date&#x3D;20240902">\n\t\t<meta property="og:image" content="https://ssl.pstatic.net/static.news/image/news/ogtag/navernews_800x420_20221201.png">\n\t\t<meta property="og:description" content="국회, 행정, 국방, 외교 등 정치 분야 뉴스 제공">\n\t\t<meta property="og:article:author" content="네이버">\n\t\t<meta name="twitter:card" content
# ...

# %%
url = "https://news.naver.com/mnews/article/comment/011/0004386530"
url = "https://apis.naver.com/commentBox/cbox/web_naver_list_jsonp.json?ticket=news&templateId=default_politics_m3&pool=cbox5&_cv=20240826125754&_callback=jQuery33109399561704461525_1725323654161&lang=ko&country=KR&objectId=news055%2C0001186810&categoryId=&pageSize=20&indexSize=10&groupId=&listType=OBJECT&pageType=more&page=2&currentPage=1&refresh=false&sort=FAVORITE&current=836045243299135503&prev=836045014642458726&moreParam.direction=next&moreParam.prev=100007r00009306co181iziteu&moreParam.next=100000i00000j06co1aykjsydr&includeAllStatus=true&_=1725323654165"


res = requests.get(url, headers= headers)
soup = BeautifulSoup(res.text, 'html.parser')
res
# Out:
# <Response [200]>

# %%
import json

# %%
news_url = "https://news.naver.com/mnews/article/comment/011/0004386530"
url = "https://apis.naver.com/commentBox/cbox/web_naver_list_jsonp.json"

params = {
    'ticket': 'news',
    'templateId': 'default_politics_m3',
    'pool': 'cbox5',
    '_cv': '20240826125754',
    '_callback': 'jQuery33105801879816582987_1725328375894',
    'lang': 'ko',
    'country': 'KR',
    'objectId': 'news011,0004386530',
    'categoryId': '',
    'pageSize': 20,
    'indexSize': 10,
    'groupId': '',
    'listType': 'OBJECT',
    'pageType': 'more',
    'page': 2,
    'currentPage': 1,
    'refresh': False,
    'sort': 'FAVORITE',
    'current': '835769145067831349',
    'prev': '835742225336893632',
    'moreParam.direction': 'next',
    'moreParam.prev': '100002100002v06cl1w61grzk0',
    'moreParam.next': '100000300000406clbfoslj41h',
    'includeAllStatus': True,
    '_': 1725329818817
}


response = requests.get(url, headers=headers, params=params)
print(response.text)
# Out:
# jQuery33105801879816582987_1725328375894({"success":false,"code":"3999","message":"잘못된 접근입니다.","lang":"ko","country":"KR","result":{},"date":"2024-09-03T08:00:15+0000","mode":0});

# %%
"100000000000106clbo36d145z" in response.text

response.text.find("100000000000106clbo36d145z")
# Out:
# 39026

# %%
response.text[38990-100:38990+100]
# Out:
# 'hold":null,"moveToLastPage":false,"moveToComment":false,"moveToLastPrev":false},"morePage":{"prev":"100002100002v06cl1w61grzk0","next":"100000000000106clbo36d145z","start":"100002100002v06cl1w61grzk0"'

# %%
res_text = response.text
res_text
# Out:
# 'jQuery33105801879816582987_1725328375894({"success":true,"code":"1000","message":"요청을 성공적으로 처리하였습니다.","lang":"ko","country":"KR","result":{"commentList":[{"ticket":"news","objectId":"news011,0004386530","categoryId":"*","templateId":"view_politics_m3","commentNo":"835762300014034965","parentCommentNo":"835762300014034965","replyLevel":1,"replyCount":0,"replyAllCount":0,"replyPreviewNo":null,"replyList":null,"imageCount":0,"imageList":null,"imagePathList":null,"imageWidthList":null,"imageHeightList":null,"commentType":"txt","stickerId":null,"sticker":null,"sortValue":1725049097588,"contents":"“국민 건강과 생명은 절대적 가치이기 때문\\" 백배공감  한다, 대안제시 나쁘지 않다, 여야와 정부는 심도있게 검토해라~","userIdNo":"3k0Ja","exposedUserIp":null,"lang":"ko","country":"KR","idType":"naver","idProvider":"naver","userName":"psgy****","userProfileImage":null,"profileType":"naver","modTime":"2024-08-31T05:18:17+0900","modTimeGmt":"2024-08-30T20:18:17+0000","regTime":"2024-08-31T05:18:17+0900","regTimeGmt":"2024-08-30T20:18:17+0000","
# ...

# %%
x = res_text.split('(')
js = json.loads(x[1][:-2])
c_list = js['result']['commentList']
len(c_list)
# Out:
# 20

# %%
js['result']['morePage']
# Out:
# {'prev': '100002100002v06cl1w61grzk0',
#  'next': '100000000000106clbo36d145z',
#  'start': '100002100002v06cl1w61grzk0',
#  'end': '0zik0zc00000206cl0rgs508iz'}

# %%
soup = BeautifulSoup(response.text, 'html.parser')

# %%
soup
# Out:
# jQuery33109399561704461525_1725323654161({"success":true,"code":"1000","message":"요청을 성공적으로 처리하였습니다.","lang":"ko","country":"KR","result":{"commentList":[{"ticket":"news","objectId":"news055,0001186810","categoryId":"*","templateId":"default_politics_m3","commentNo":"836044790180085772","parentCommentNo":"836044790180085772","replyLevel":1,"replyCount":0,"replyAllCount":0,"replyPreviewNo":null,"replyList":null,"imageCount":0,"imageList":null,"imagePathList":null,"imageWidthList":null,"imageHeightList":null,"commentType":"txt","stickerId":null,"sticker":null,"sortValue":1725312186611,"contents":"무능자  권력욕만 있는 간신  꼬짜 좋아하는  대머리  자신도  속이는 자가  이재명과  결탁하는자  이재명과  별반  다르지  않은자","userIdNo":"58n2P","exposedUserIp":null,"lang":"ko","country":"KR","idType":"naver","idProvider":"naver","userName":"s_su****","userProfileImage":null,"profileType":"naver","modTime":"2024-09-03T06:23:06+0900","modTimeGmt":"2024-09-02T21:23:06+0000","regTime":"2024-09-03T06:23:06+0900","regTimeGmt":"2024-09-02T21:23:0
# ...

# %%
boxes[0]
# Out:
# <div class="_COMMENT _COMMENT_HIDE" id="cbox_module">
# </div>

# %%
import requests

# JavaScript에서 확인한 API URL
url = 'https://n.news.naver.com/mnews/article/comment/011/0004386530'
headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/127.0.0.0 Safari/537.36'}

# 필요하면 헤더나 파라미터도 함께 전송
params = {
'ticket': 'news',
'templateId': 'default_politics_m3',
'pool': 'cbox5',
'_cv': '20240826125754',
'_callback': 'jQuery33107127762849002859_1725265369375',
'lang': 'ko',
'country': 'KR',
'objectId': 'news011%2C0004386530',
'pageSize': '20',
'indexSize': '10',
'listType': 'OBJECT',
'pageType': 'more',
'page': '3',
'currentPage': '2',
'refresh': 'false',
'sort': 'FAVORITE',
'current': '835769803288346711',
'prev': '835742225336893632',
'moreParam.direction': 'next',
'moreParam.prev': '100002100002v06cl1w61grzk0',
'moreParam.next': '100000000000106clbo36d145z',
'includeAllStatus': 'true',
'_': '1725265369380'
}

# GET 요청으로 데이터를 가져옴
response = requests.get(url, headers=headers, params=params)

# 응답을 JSON 형식으로 파싱
# data = response.json()

# print(data)

# %%
response.text
# Out:
# '<!doctype html>\n<html lang="ko" data-useragent="Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/127.0.0.0 Safari/537.36">\n\t<head>\n\t\t<meta charset="utf-8">\n\t\t<meta http-equiv="X-UA-Compatible" content="IE=edge">\n\t\t<meta name="viewport" content="width=device-width, initial-scale=1.0, maximum-scale=1.0, minimum-scale=1.0, user-scalable=no" />\n\t\t<meta property="og:title" content="한동훈, 尹과 갈등설에 &quot;본질 가리려는 시도&quot;">\n\t\t<meta property="og:type" content="article">\n\t\t<meta property="og:url" content="https://n.news.naver.com/mnews/article/011/0004386530">\n\t\t<meta property="og:image" content="https://imgnews.pstatic.net/image/011/2024/08/30/0004386530_001_20240830221810139.jpg?type&#x3D;w800">\n\t\t<meta property="og:description" content="한동훈 국민의힘 대표가 30일 의·정 갈등 해법을 둘러싸고 윤석열 대통령과 갈등을 겪고 있다는 시각에 대해 “갈등 프레임은 본질을 가리려는 시도”라고 반박했다. 한 대표는 이날 자신의 페이스북에서 &quot;우리는 지금 국민">\n\t\t<meta property="og:article:author" content="서울경제 | 네이버">\n\t
# ...

# %%
for box in boxes:
    articles = box.select('div.sa_text')
    # print(len(articles))
    for article in articles:
        # 제목, url, 언론사 # 댓글수
        title = article.select_one('strong.sa_text_strong').text
        news_url = article.select_one('a')['href']
        news_id = news_url.split('/')[-1]
        press = article.select_one('div.sa_text_press').text
        print(title[:10], press, news_id)
# Out:
# 6월 은행 예금·대 연합뉴스TV 0000673983
# [이코노미 플러스] 강원일보 0001059409
# 삼성증권 새 IB1 뉴시스 0012701537
# 부산은행 끌고, 경 국제신문 0000080042
# 일본은행, 4개월만 디지털타임스 0002891958
# KB손보, 115명 세계일보 0003955998
# 하나銀 반년 만에  디지털타임스 0002891952
# [마켓인]“1조 규 이데일리 0005801740
# 키움증권 2분기 영 한겨레 0002700653
# 푸본현대생명, 소외 이데일리 0005801739
# 3년 만에 희망퇴직 파이낸셜뉴스 0005221644
# 손해보험협회, 우수 매일경제 0005343494
# KB손보, 36개월 디지털타임스 0002891940
# 김병환 금융위원장  이데일리 0005801715
# 일본은행 단기 정책 매일신문 0000895228
# 삼성전자 추격하는  매일신문 0000895226
# `환승 대출` 23 디지털타임스 0002891933
# 우수설계사 인증 ‘ 국민일보 0001714805
# [오일 Drive] 이데일리 0005801704
# BNK금융그룹, 예 부산일보 0001282011
# 美 금리인하 예상  파이낸셜뉴스 0005221602
# BNK·JB 웃고  매일경제 0005343476
# [표] 외국환율고시 매일경제 0005343475
# 티메프 환불 떠안은 매일경제 0005343474
# 취임식 생략한 금융 매일경제 0005343473
# [표] 당좌거래정지 매일경제 0005343472
# 부동산PF 연체액  매일경제 0005343470
# 주담대 금리 8개월 국민일보 0001714802
# "경제 불확실성 도 파이낸셜뉴스 0005221572
# 손보협, ‘불완전판 파이낸셜뉴스 0005221571
# "티메프 사태 신속 파이낸셜뉴스 0005221570
# 국민銀 노사 ‘1천 파이낸셜뉴스 0005221569
# 강신숙 행장 "내부 파이낸셜뉴스 0005221568
# ...

# %%
import datetime
import calendar

p_next = soup.select_one('div.section_latest_article')['data-cursor']

t = datetime.datetime.now()
p_time = calendar.timegm(t.timetuple())

p_next, p_time
# Out:
# ('2024073116521181976', 1725138398)

# %% [markdown]
# 1725105317255

# %% [markdown]
# 다음 페이지

# %%
next_url = f"https://news.naver.com/section/template/SECTION_ARTICLE_LIST_FOR_LATEST?sid=101&sid2=259&cluid=&pageNo=1&date=20240731&next={p_next}&_={p_time}"
next_url
# Out:
# 'https://news.naver.com/section/template/SECTION_ARTICLE_LIST_FOR_LATEST?sid=101&sid2=259&cluid=&pageNo=1&date=20240731&next=2024073118000909056&_=1725137962'

# %%
res = requests.get(next_url, headers= headers)
res
# Out:
# <Response [200]>

# %%
import json

# %%
content_json = json.loads(res.text)
content_json
# Out:
# {'component': {},
# ...

# %%
res_text = content_json['renderedComponent']['SECTION_ARTICLE_LIST_FOR_LATEST']

# %%
soup = BeautifulSoup(res_text, 'html.parser')

# %%
boxes = soup.select('ul.sa_list')
len(boxes)
# Out:
# 6

# %%
for box in boxes:
    articles = box.select('div.sa_text')
    # print(len(articles))
    for article in articles:
        # 제목, url, 언론사 # 댓글수
        title = article.select_one('strong.sa_text_strong').text
        news_url = article.select_one('a')['href']
        news_id = news_url.split('/')[-1]
        press = article.select_one('div.sa_text_press').text
        print(title[:], press, sep=' / ')
# Out:
# KB국민은행, 금융 취약계층에 ‘따뜻한 금융’의 손길 / 스포츠서울
# 김병환 신임 금융위원장 "티메프 사태 지원, 꼼꼼히 챙기겠다"[이슈+] / 이코노미스트
# "4대 리스크 해소"…김병환號 '티메프'가 첫 시험대 / 서울경제
# 금융당국 "e커머스 정산주기 단축…PG사 관리체계도 손질" / 한국경제
# 임태중 상상인증권 대표, 임기 8개월 남기고 사임 / 연합뉴스
# 5대銀 대출금리 뚝뚝…예대차 두달 연속 축소 / 서울경제
# 저축은행 토지담보대출 연체율 20%로 껑충 / 한국경제
# 김병환 "가계부채 철저 관리" / 한국경제
# 주담대 금리, 30개월 만에 최저 / 한국경제
# 하이투자증권, 비대면 신규 고객 거래 수수료 0.01% 이벤트 / 서울경제
# 하나은행, 상반기 상생금융지원 3207억원 투입 / 이데일리
# 주담대 갈아타기 수수료율, 네이버페이가 낮네 / 한국경제
# "5년간 불완전판매 제로"…손보 최고 설계사 2807명 / 한국경제
# 농협은행 강원본부, 소상공인을 위한 첫걸음 금융지원 협약식 / 연합뉴스
# 우리은행, 소장도서 2만5000권 밀알복지재단에 기부...도서판매 수익금도 쾌척 / 스포츠서울
# 신한카드 "서울시 골목상권 이용하면 7000원 돌려줘요" / 디지털타임스
# 삼성증권, 이충훈 부사장 신임 IB1부문장 임명 / 디지털타임스
# 라이나손보, 취약계층 아동 지원 / 한국경제
# 우리은행, 소장도서 2만5000권 기부 / 한국경제
# 하나금융 계열 하나대체투자 도덕적 해이에 철거업체는 부도 직전 몰려 / 매일신문
# "일본 금리 인상"…한국 금융시장 영향은 / 뉴시스
# 신한은행, 상반기 민생금융지원 2436억원 투입 / 이데일리
# 국민은행, 3721억원 규모 민생금융 지원 / 이데일리
# 비은행 계열사 따라 실적 '희비'..BNK·JB 웃고 DGB 울고 / 머니투데이
# 국고채 금리, '매파 금통위'에 일제히 상승…3년물 3.004%(종합) / 연합뉴스
# ...

# %%
p_next = soup.select_one('div.section_latest_article')['data-cursor']

t = datetime.datetime.now()
p_time = calendar.timegm(t.timetuple())

p_next, p_time
# Out:
# ('2024073116521181976', 1725140147)

# %%
p_next = "2024073100003709141"

# %%
date_str = '20240731'

next_url = f"https://news.naver.com/section/template/SECTION_ARTICLE_LIST_FOR_LATEST?sid=101&sid2=259&cluid=&pageNo=1&date={date_str}&next={p_next}&_={p_time}"
next_url
# Out:
# 'https://news.naver.com/section/template/SECTION_ARTICLE_LIST_FOR_LATEST?sid=101&sid2=259&cluid=&pageNo=1&date=20240731&next=2024073100003709141&_=1725140147'

# %%
res = requests.get(next_url, headers= headers)
content_json = json.loads(res.text)
res_text = content_json['renderedComponent']['SECTION_ARTICLE_LIST_FOR_LATEST']
soup = BeautifulSoup(res_text, 'html.parser')

# %%
p_next = soup.select_one('div.section_latest_article')['data-cursor']
p_time = calendar.timegm(dt.datetime.now().timetuple())
p_next
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[73], line 1
# ----> 1 p_next = soup.select_one('div.section_latest_article')['data-cursor']
#       2 p_time = calendar.timegm(dt.datetime.now().timetuple())
#       3 p_next
#
# TypeError: 'NoneType' object is not subscriptable
